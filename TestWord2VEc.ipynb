# %%
from bd_gensim.doc2vec_facade import Doc2VecFacade
import yaml

# %%
config = yaml.safe_load(open("config.yml"))
data_dir = config['data_dir']
models_dir = config['models_dir']

# %%
doc2VecFacade = Doc2VecFacade(models_dir)

# %%
doc2VecFacade.load_models()

# %%
model = doc2VecFacade.model

# %%
model.wv.vocab
# Out:
# {'mit': <gensim.models.keyedvectors.Vocab at 0x7f6d257daf28>,
#  'datum': <gensim.models.keyedvectors.Vocab at 0x7f6d25783048>,
#  'muss': <gensim.models.keyedvectors.Vocab at 0x7f6d257830b8>,
#  'im_online-banking': <gensim.models.keyedvectors.Vocab at 0x7f6d257830f0>,
#  'anmelden': <gensim.models.keyedvectors.Vocab at 0x7f6d25783128>,
#  'um': <gensim.models.keyedvectors.Vocab at 0x7f6d25783198>,
#  'pushtan-verfahren': <gensim.models.keyedvectors.Vocab at 0x7f6d257831d0>,
#  'nutzen': <gensim.models.keyedvectors.Vocab at 0x7f6d25783240>,
#  'erhalten': <gensim.models.keyedvectors.Vocab at 0x7f6d25783278>,
#  'für': <gensim.models.keyedvectors.Vocab at 0x7f6d257832b0>,
#  'pushtan': <gensim.models.keyedvectors.Vocab at 0x7f6d25783320>,
#  'neu': <gensim.models.keyedvectors.Vocab at 0x7f6d25783390>,
#  'anmeldename': <gensim.models.keyedvectors.Vocab at 0x7f6d257833c8>,
#  'neue': <gensim.models.keyedvectors.Vocab at 0x7f6d25783438>,
# ...

# %%
model.most_similar('girokonto')
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('spar30-', 0.27795538306236267),
#  ('vernünftig', 0.26425519585609436),
#  ('konto', 0.26378118991851807),
#  ('geschäftsgirokonto', 0.2619224786758423),
#  ('aufgeteilt', 0.23595088720321655),
#  ('starter-konto', 0.2358391433954239),
#  ('geworbene', 0.23259097337722778),
#  ('euro_pro', 0.23251868784427643),
#  ('sparbetrag', 0.22427672147750854),
#  ('webseite', 0.2213200032711029)]

# %%
model.most_similar('baukredit')
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('möchen', 0.48014527559280396),
#  ('dabeihelfen', 0.43367207050323486),
#  ('beratungsstelle', 0.3674114942550659),
#  ('festgeldbetrag', 0.36362627148628235),
#  ('aktiv-sparcard', 0.35980674624443054),
#  ('tilgungen', 0.35166460275650024),
#  ('gewinn-sparcard', 0.34592801332473755),
#  ('quartal-sparcard', 0.3451182246208191),
#  ('familienstandsänderung', 0.3354114890098572),
#  ('gold-sparcard', 0.33112213015556335)]

# %%
model.most_similar('sparkonto')
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('vorprüfung', 0.22925768792629242),
#  ('wertpapiersparplan', 0.22897522151470184),
#  ('gewählt', 0.2270386666059494),
#  ('amro', 0.2203884720802307),
#  ('gemeldet', 0.2199104130268097),
#  ('briefsymbol', 0.21962061524391174),
#  ('geschäftsvorfall', 0.2123783826828003),
#  ('einzeldepot', 0.2113545686006546),
#  ('fingerbewegungen', 0.21097862720489502),
#  ('einzug', 0.20817020535469055)]

# %%
model.most_similar('festgeld')
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('außerbörslichem', 0.2557833194732666),
#  ('problem', 0.2494092732667923),
#  ('cardtan-verfahren', 0.24639588594436646),
#  ('banking-app', 0.2440958023071289),
#  ('internetverbindung', 0.23540620505809784),
#  ('kreditnehmer', 0.23518012464046478),
#  ('premium-konto', 0.23292118310928345),
#  ('abruf', 0.23078234493732452),
#  ('depot', 0.23003746569156647),
#  ('festgeldkonto', 0.22584158182144165)]

# %%
model.most_similar('p-konto',topn=25)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('pfändungsschutzkonto', 0.3284425139427185),
#  ('test', 0.31896060705184937),
#  ('prepaidkarte', 0.30890315771102905),
#  ('höchstgrenze', 0.30009737610816956),
#  ('pfändungsfreibetrag', 0.28359073400497437),
#  ('p-konto-schutz', 0.2780841290950775),
#  ('überweisungsauftrag', 0.2724277377128601),
#  ('amexco', 0.27004188299179077),
#  ('orderkonto', 0.2565835118293762),
#  ('pharming', 0.25620535016059875),
#  ('pfändung', 0.2516743540763855),
#  ('vereinigung', 0.24855497479438782),
#  ('p-konten', 0.24617637693881989),
#  ('überziehungsrahmen', 0.24304266273975372),
#  ('vvtq', 0.2412063330411911),
#  ('freibetrag', 0.23774519562721252),
#  ('pfüb', 0.2372293323278427),
# ...

# %%
model.most_similar('kreditkarte',topn=25)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('karten', 0.2573468089103699),
#  ('cards', 0.25533610582351685),
#  ('visacard', 0.23916205763816833),
#  ('vereinbarung', 0.22838947176933289),
#  ('ambibankkonto', 0.2242906391620636),
#  ('kreditbedarf', 0.21745283901691437),
#  ('kreditentscheidung', 0.21733079850673676),
#  ('eingeräumt_kontoüberziehung_dispo', 0.2153657078742981),
#  ('buchung', 0.21398262679576874),
#  ('zugang', 0.21388773620128632),
#  ('im_internetbanking', 0.21113231778144836),
#  ('scheckbetrag', 0.2084268480539322),
#  ('18', 0.20721232891082764),
#  ('online-kredit', 0.20211058855056763),
#  ('e-mail-adresse', 0.20059803128242493),
#  ('dispokredit', 0.1985870897769928),
#  ('kontoeröffnung', 0.19790518283843994),
# ...

# %%
model.most_similar('v_pay',topn=25)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('cashgroup', 0.3608890771865845),
#  ('elfstellig', 0.33371901512145996),
#  ('lastschriftprodukten', 0.32597649097442627),
#  ('oglietzen_oglietzen', 0.32472431659698486),
#  ('surprize', 0.32123950123786926),
#  ('online-freundschaftswerbung', 0.31676435470581055),
#  ('etin', 0.31172698736190796),
#  ('ab_wann', 0.31106001138687134),
#  ('ca', 0.3108094334602356),
#  ('fachhandel', 0.3076469302177429),
#  ('euro-zahlungen', 0.3066019117832184),
#  ('überweisungs', 0.3060515522956848),
#  ('währungsumrechnung', 0.30238139629364014),
#  ('geldkartenfunktion', 0.30200478434562683),
#  ('geldkarten-chip', 0.3015230596065521),
#  ('bürgschaft', 0.29864805936813354),
#  ('abkönnen', 0.29769250750541687),
# ...

# %%
for word, vocab_obj in model.wv.vocab.items():
    print(word, vocab_obj)
# Out:
# mit Vocab(count:3399, index:2, sample_int:1442573940)
# datum Vocab(count:666, index:31, sample_int:4119633031)
# muss Vocab(count:608, index:34, sample_int:4294967296)
# im_online-banking Vocab(count:283, index:107, sample_int:4294967296)
# anmelden Vocab(count:200, index:160, sample_int:4294967296)
# um Vocab(count:907, index:18, sample_int:3340786983)
# pushtan-verfahren Vocab(count:46, index:850, sample_int:4294967296)
# nutzen Vocab(count:887, index:19, sample_int:3391096095)
# erhalten Vocab(count:1138, index:14, sample_int:2873939490)
# für Vocab(count:4454, index:1, sample_int:1226779759)
# pushtan Vocab(count:47, index:835, sample_int:4294967296)
# neu Vocab(count:522, index:39, sample_int:4294967296)
# anmeldename Vocab(count:19, index:1953, sample_int:4294967296)
# neue Vocab(count:375, index:67, sample_int:4294967296)
# legitimations-id Vocab(count:13, index:2694, sample_int:4294967296)
# online-banking-pin Vocab(count:15, index:2407, sample_int:4294967296)
# ...

# %%
cw_l = []
for word, vocab_obj in model.wv.vocab.items():
    cw_l.append((word, vocab_obj.count))
cw_s = sorted(cw_l, key=lambda x : x[1], reverse=True)

# %%
cw_s
# Out:
# [('können', 5848),
#  ('für', 4454),
#  ('mit', 3399),
#  ('bei', 3328),
#  ('in', 3281),
#  ('von', 3079),
#  ('auf', 2676),
#  ('auch', 1915),
#  ('wenn', 1659),
#  ('über', 1592),
#  ('an', 1543),
#  ('im', 1491),
#  ('wie', 1485),
#  ('konto', 1184),
#  ('erhalten', 1138),
#  ('nur', 1009),
#  ('bank', 952),
#  ('als', 942),
#  ('um', 907),
#  ('nutzen', 887),
#  ('nach', 849),
#  ('dass', 812),
#  ('zu', 799),
#  ('kunde', 788),
#  ('didibank', 740),
#  ('zur', 729),
#  ('müssen', 726),
#  ('dann', 717),
#  ('möglich', 715),
#  ('durch', 711),
#  ('zum', 696),
#  ('datum', 666),
#  ('unter', 655),
#  ('didi', 646),
#  ('muss', 608),
#  ('aus', 567),
#  ('sollen', 563),
#  ('beim', 558),
#  ('zum_beispiel', 552),
#  ('neu', 522),
#  ('karten', 518),
#  ('so', 512),
#  ('girokonto', 512),
#  ('online-banking', 506),
#  ('bitte', 494),
#  ('erfolgen', 485),
#  ('benötigen', 478),
#  ('geben', 476),
#  ('finden', 466),
#  ('überweisung', 461),
#  ('transaktion', 461),
# ...

# %%
model.most_similar('didibank',topn=25)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('didi_bank', 0.2907456159591675),
#  ('wohnungseigentümern', 0.2441776841878891),
#  ('didibank_bank', 0.236110121011734),
#  ('orderprovisionen', 0.23610331118106842),
#  ('freizuschalten', 0.2347913384437561),
#  ('belasten', 0.21955017745494843),
#  ('nichtbezahlen', 0.21539083123207092),
#  ('sofortumrechnung', 0.21043670177459717),
#  ('esafe', 0.2068445235490799),
#  ('online-filiale', 0.2012847512960434),
#  ('europäische_union', 0.19776223599910736),
#  ('kreditinstitut', 0.197018563747406),
#  ('ing-diba', 0.1953577846288681),
#  ('online-sicherheits-garantie', 0.19513332843780518),
#  ('3-mal', 0.19391058385372162),
#  ('mittler', 0.19340620934963226),
#  ('pc', 0.19184085726737976),
# ...

# %%
model.most_similar('online-banking',topn=50)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('mobilebanking', 0.3021238446235657),
#  ('hbci-banking', 0.27531901001930237),
#  ('bambi-app', 0.2664628028869629),
#  ('banking-terminals', 0.2658084034919739),
#  ('videoid', 0.26246896386146545),
#  ('e-banking', 0.253022700548172),
#  ('eröffnend', 0.250227689743042),
#  ('telefon-brokerage', 0.2452174723148346),
#  ('unioninvestment', 0.24165134131908417),
#  ('vormonats', 0.2405487447977066),
#  ('ambibank_online-banking', 0.24022763967514038),
#  ('mobile-banking', 0.23818908631801605),
#  ('spardaapp', 0.2379276305437088),
#  ('online-kredit', 0.23665735125541687),
#  ('verstoß', 0.2360682487487793),
#  ('auswahlfeld', 0.23510700464248657),
#  ('finanzassistenten', 0.23474033176898956),
# ...
