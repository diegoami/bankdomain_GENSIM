# %%
from bd_gensim.doc2vec_facade import Doc2VecFacade
import yaml

# %%
config = yaml.safe_load(open("config.yml"))
data_dir = config['data_dir']
models_dir = config['models_dir']

# %%
doc2VecFacade = Doc2VecFacade(models_dir)

# %%
doc2VecFacade.load_models()

# %%
model = doc2VecFacade.model

# %%
cw_l = []
for word, vocab_obj in model.wv.vocab.items():
    cw_l.append((word, vocab_obj.count))
cw_s = sorted(cw_l, key=lambda x : x[1], reverse=True)

# %%
cw_s
# Out:
# [('sein', 6134),
#  ('können', 5837),
#  ('werden', 5553),
#  ('für', 4456),
#  ('mit', 3377),
#  ('in', 3235),
#  ('bei', 3234),
#  ('von', 3014),
#  ('auf', 2589),
#  ('auch', 1915),
#  ('haben', 1837),
#  ('wenn', 1663),
#  ('über', 1545),
#  ('an', 1503),
#  ('wie', 1475),
#  ('im', 1422),
#  ('konto', 1169),
#  ('erhalten', 1139),
#  ('nur', 1009),
#  ('um', 907),
#  ('neu', 907),
#  ('bank', 892),
#  ('nutzen', 859),
#  ('als', 826),
#  ('nach', 811),
#  ('dass', 774),
#  ('zu', 767),
#  ('kunde', 728),
#  ('müssen', 717),
#  ('didibank', 716),
#  ('durch', 711),
#  ('dann', 690),
#  ('zur', 690),
#  ('möglich', 686),
#  ('zum', 665),
#  ('didi', 648),
#  ('datum', 642),
#  ('unter', 624),
#  ('muss', 595),
#  ('sollen', 563),
#  ('beim', 558),
#  ('zum_beispiel', 552),
#  ('aus', 545),
#  ('online-banking', 517),
#  ('karten', 510),
#  ('geben', 494),
#  ('girokonto', 482),
#  ('benötigen', 478),
#  ('erfolgen', 471),
#  ('bitte', 466),
#  ('finden', 465),
#  ('transaktion', 461),
#  ('pin', 459),
#  ('so', 452),
#  ('weit', 445),
#  ('noch', 442),
#  ('automatisch', 439),
#  ('überweisung', 435),
#  ('ändern', 414),
#  ('ander', 394),
#  ('betragen', 394),
#  ('zusätzlich', 385),
#  ('geld', 384),
#  ('kreditkarte', 379),
#  ('bitten', 379),
#  ('vom', 379),
#  ('am', 377),
#  ('aktuell', 374),
#  ('kredit', 373),
#  ('auftrag', 370),
#  ('mögen', 369),
#  ('direkt', 366),
#  ('zahlung', 356),
#  ('verwenden', 353),
#  ('damit', 353),
#  ('zins', 353),
#  ('mein', 348),
#  ('ohne', 347),
#  ('kosten', 344),
#  ('kostenlos', 339),
#  ('hier', 337),
#  ('sichern', 336),
#  ('einfach', 334),
#  ('stehen', 334),
#  ('ambibank', 334),
#  ('eingeben', 330),
#  ('angeben', 330),
#  ('euro', 329),
#  ('bereits', 323),
#  ('vor', 321),
#  ('immer', 318),
#  ('tan', 316),
#  ('da', 311),
#  ('app', 308),
#  ('sicherheit', 308),
#  ('kontoauszug', 301),
#  ('dazu', 300),
#  ('beantragen', 298),
#  ('mehr', 297),
#  ('banken', 296),
#  ('persönlich', 293),
#  ('jedoch', 292),
#  ('online', 290),
#  ('anzeigen', 290),
#  ('jahr', 289),
#  ('anbieten', 286),
#  ('im_online-banking', 283),
#  ('eur', 282),
#  ('gelten', 281),
#  ('eröffnen', 281),
#  ('verfahren', 279),
#  ('information', 277),
#  ('habe', 274),
#  ('unternehmen', 267),
#  ('dabei', 266),
#  ('monat', 266),
#  ('ob', 265),
#  ('hoch', 264),
#  ('fall', 261),
#  ('per', 258),
#  ('jederzeit', 256),
#  ('bekommen', 252),
#  ('lassen', 251),
#  ('stellen', 250),
#  ('in_fall', 249),
#  ('änderung', 249),
#  ('aktivieren', 248),
#  ('tagesgeldkonto', 248),
#  ('funktion', 245),
#  ('bieten', 244),
#  ('service', 239),
#  ('wählen', 238),
#  ('unterliegen', 237),
#  ('folgend', 234),
#  ('formular', 234),
#  ('möglichkeit', 233),
#  ('didi_bank', 233),
#  ('bezahlen', 232),
#  ('erst', 231),
#  ('entsprechend', 228),
#  ('antrag', 226),
#  ('zwischen', 225),
#  ('nutzung', 223),
#  ('bestimmen', 221),
#  ('%', 221),
#  ('tagen', 219),
#  ('gut', 219),
#  ('ist', 218),
#  ('speichern', 217),
#  ('gerät', 215),
#  ('warum', 215),
#  ('passwort', 214),
#  ('erforderlich', 214),
#  ('sperren', 211),
#  ('ab', 210),
#  ('freistellungsauftrag', 210),
#  ('handeln', 209),
#  ('informieren', 208),
#  ('aber', 208),
#  ('zur_verfügung', 207),
#  ('in_poltawien', 203),
#  ('name', 202),
#  ('machen', 202),
#  ('anmelden', 200),
#  ('wertpapier', 200),
#  ('selbst', 196),
#  ('löschen', 196),
#  ('dürfen', 195),
#  ('gehen', 195),
#  ('daher', 195),
#  ('sofort', 195),
#  ('gültig', 195),
#  ('in_regeln', 194),
#  ('bestätigen', 194),
#  ('jetzt', 194),
#  ('also', 191),
#  ('sofern', 190),
#  ('schützen', 190),
#  ('mastercard', 190),
#  ('wann', 190),
#  ('dort', 189),
#  ('depot', 189),
#  ('grundsätzlich', 188),
#  ('person', 187),
#  ('jeweilig', 185),
#  ('zahlen', 184),
#  ('laufzeit', 182),
#  ('dafür', 182),
#  ('während', 181),
#  ('kommen', 181),
#  ('berechnen', 178),
#  ('bestehen', 176),
#  ('verfügen', 176),
#  ('wichtig', 171),
#  ('prüfen', 170),
#  ('anlegen', 169),
#  ('schufa', 168),
#  ('individuell', 167),
#  ('zinssatz', 167),
#  ('umsatz', 165),
#  ('überweisen', 165),
#  ('girocard', 164),
#  ('höhe', 164),
#  ('z._b.', 163),
#  ('bedeuten', 163),
#  ('händler', 162),
#  ('guthaben', 161),
#  ('bis_zu', 161),
#  ('paydirekt', 161),
#  ('kontoinhaber', 160),
#  ('bleiben', 159),
#  ('aktie', 159),
#  ('wieder', 158),
#  ('gerne', 158),
#  ('poltawien', 158),
#  ('geschäftskonto', 157),
#  ('angebot', 157),
#  ('liegen', 157),
#  ('smartphone', 156),
#  ('nun', 156),
#  ('registrieren', 156),
#  ('bis', 155),
#  ('dokument', 155),
#  ('erteilen', 155),
#  ('kostenfrei', 154),
#  ('unterstützen', 154),
#  ('browser', 154),
#  ('auswählen', 153),
#  ('sicher', 153),
#  ('zeit', 152),
#  ('ausschließlich', 152),
#  ('verschieden', 151),
#  ('darlehen', 151),
#  ('einrichten', 149),
#  ('einstellung', 148),
#  ('senden', 148),
#  ('innerhalb', 148),
#  ('kreditinstitut', 148),
#  ('neben', 148),
#  ('sobald', 147),
#  ('vorteil', 147),
#  ('kondition', 147),
#  ('kaufen', 147),
#  ('gewünscht', 146),
#  ('sehen', 146),
#  ('telefonisch', 145),
#  ('monatlich', 145),
#  ('notwendig', 144),
#  ('eigen', 144),
#  ('ordern', 143),
#  ('referenzkonto', 143),
#  ('didi_direct', 143),
#  ('eingabe', 142),
#  ('hinterlegen', 142),
#  ('überprüfen', 141),
#  ('erreichen', 140),
#  ('p-konto', 140),
#  ('erneut', 139),
#  ('gegebenenfalls', 139),
#  ('€', 137),
#  ('im_rahmen', 137),
#  ('erstellen', 135),
#  ('zugangsdaten', 135),
#  ('übertragen', 135),
#  ('somit', 135),
#  ('lastschrift', 135),
#  ('schon', 135),
#  ('führen', 134),
#  ('wie_funktionieren', 134),
#  ('abschließen', 134),
#  ('fahren', 133),
#  ('mitteilen', 133),
#  ('beachten', 133),
#  ('groß', 133),
#  ('melden', 132),
#  ('mtan', 132),
#  ('deutsch', 132),
#  ('im_ausland', 132),
#  ('sehr', 132),
#  ('gibt', 132),
#  ('vorliegen', 131),
#  ('klicken', 131),
#  ('öffnen', 131),
#  ('weiterhin', 131),
#  ('regelmäßig', 130),
#  ('einreichen', 130),
#  ('wollen', 129),
#  ('entsprechen', 129),
#  ('nachricht', 129),
#  ('auszahlung', 128),
#  ('aus_sicherheitsgrund', 127),
#  ('entscheiden', 127),
#  ('enthalten', 127),
#  ('seite', 126),
#  ('gebühr', 126),
#  ('berücksichtigen', 126),
#  ('computer', 126),
#  ('hierzu', 125),
#  ('registrierung', 125),
#  ('voraussetzung', 125),
#  ('genau', 125),
#  ('setzen', 125),
#  ('verfügbar', 125),
#  ('kontonummer', 124),
#  ('beispielsweise', 124),
#  ('außerdem', 124),
#  ('fond', 123),
#  ('kündigen', 123),
#  ('per_post', 122),
#  ('dauerauftrag', 121),
#  ('schriftlich', 121),
#  ('allerdings', 120),
#  ('nächst', 120),
#  ('url', 119),
#  ('durchfahren', 119),
#  ('•', 118),
#  ('sms', 117),
#  ('rechnung', 117),
#  ('betrag', 117),
#  ('ebenfalls', 116),
#  ('e-mail', 115),
#  ('tun', 114),
#  ('empfehlen', 114),
#  ('produkt', 114),
#  ('bic', 114),
#  ('iban', 114),
#  ('teilen', 114),
#  ('festgeld', 114),
#  ('bestehend', 113),
#  ('wo', 113),
#  ('vornehm', 113),
#  ('geldautomat', 113),
#  ('vollständig', 113),
#  ('kontoeröffnung', 112),
#  ('privat', 112),
#  ('versicherung', 112),
#  ('halten', 111),
#  ('bitten_beachten_dass', 111),
#  ('anfallen', 111),
#  ('darüber_hinaus', 111),
#  ('verwalten', 110),
#  ('verkaufen', 110),
#  ('filiale', 110),
#  ('anmeldung', 109),
#  ('soll', 109),
#  ('hinweis', 109),
#  ('vergeben', 109),
#  ('hierfür', 108),
#  ('adresse', 108),
#  ('maximal', 108),
#  ('karte', 108),
#  ('bestellen', 107),
#  ('minderjährig', 107),
#  ('vereinbart', 107),
#  ('3d_secure', 107),
#  ('installieren', 106),
#  ('sogenannt', 106),
#  ('schnellen', 106),
#  ('wird', 106),
#  ('brauchen', 106),
#  ('fragen', 105),
#  ('alt', 105),
#  ('jeweils', 105),
#  ('alternativ', 104),
#  ('gegen', 104),
#  ('finden_hier', 104),
#  ('recht', 104),
#  ('oglietzen', 104),
#  ('mindestens', 103),
#  ('zudem', 102),
#  ('haben_möglichkeit', 102),
#  ('pc', 102),
#  ('buchung', 102),
#  ('einlagensicherung', 102),
#  ('per_e-mail', 101),
#  ('im_internet', 101),
#  ('software', 100),
#  ('dienen', 100),
#  ('gesetzlich', 100),
#  ('pro', 99),
#  ('einsehen', 98),
#  ('ausfüllen', 98),
#  ('anfordern', 97),
#  ('unterschreiben', 97),
#  ('wechseln', 97),
#  ('ag', 97),
#  ('gemeinsam', 97),
#  ('seit', 97),
#  ('aufklicken', 96),
#  ('elektronisch', 96),
#  ('hbci', 96),
#  ('lediglich', 96),
#  ('problem', 96),
#  ('vornehmen', 95),
#  ('limit', 95),
#  ('system', 95),
#  ('auszahlen', 95),
#  ('kurs', 95),
#  ('eigene', 94),
#  ('übernehmen', 94),
#  ('je_nach', 94),
#  ('empfänger', 94),
#  ('in_filiale', 94),
#  ('verpflichten', 94),
#  ('oft', 94),
#  ('kündigung', 94),
#  ('unterschiedlich', 93),
#  ('einsetzen', 93),
#  ('unterschrift', 93),
#  ('finanzierung', 92),
#  ('bargeld', 92),
#  ('natürlich', 92),
#  ('zusenden', 91),
#  ('land', 91),
#  ('gläubiger', 91),
#  ('zeitraum', 91),
#  ('festgeldkonto', 91),
#  ('wenden', 91),
#  ('mitarbeiter', 91),
#  ('bestätigung', 90),
#  ('zugang', 90),
#  ('akzeptieren', 90),
#  ('danach', 89),
#  ('bitten_beachten', 89),
#  ('zunächst', 89),
#  ('arbeiten', 89),
#  ('beispiel', 89),
#  ('aufgrund', 89),
#  ('letzt', 89),
#  ('login', 89),
#  ('deshalb', 88),
#  ('banking', 88),
#  ('wo_finden', 88),
#  ('wo_können', 88),
#  ('wert', 88),
#  ('übermitteln', 87),
#  ('version', 87),
#  ('sollte', 87),
#  ('entgelt', 87),
#  ('täglich', 86),
#  ('erscheinen', 86),
#  ('einmalig', 86),
#  ('uhr', 86),
#  ('günstig', 86),
#  ('einliegen', 86),
#  ('richtig', 85),
#  ('mitteilung', 85),
#  ('anschließen', 85),
#  ('ermöglichen', 85),
#  ('erhöhen', 85),
#  ('versenden', 85),
#  ('bequemen', 85),
#  ('gesamt', 84),
#  ('einloggen', 84),
#  ('prüfung', 84),
#  ('einkauf', 84),
#  ('funktionieren', 84),
#  ('erfüllen', 84),
#  ('vergleichen', 84),
#  ('kurz', 84),
#  ('spät', 84),
#  ('mittels', 83),
#  ('weg', 83),
#  ('weltweit', 83),
#  ('nummer', 83),
#  ('ganz', 83),
#  ('vorhanden', 82),
#  ('tätig', 82),
#  ('immobilie', 82),
#  ('weil', 82),
#  ('dadurch', 81),
#  ('1', 81),
#  ('zugriff_auf', 81),
#  ('link', 81),
#  ('tätigen', 81),
#  ('frage', 81),
#  ('anleger', 81),
#  ('bonität', 81),
#  ('kirchensteuer', 81),
#  ('auffordern', 80),
#  ('einmal', 80),
#  ('in_höhe', 80),
#  ('indem', 80),
#  ('festlegen', 80),
#  ('einkommen', 80),
#  ('einzahlen', 80),
#  ('legitimieren', 79),
#  ('listen', 79),
#  ('vertragen', 79),
#  ('prozent', 79),
#  ('gering', 79),
#  ('empfangen', 78),
#  ('nachdem', 78),
#  ('falsch', 78),
#  ('sind', 78),
#  ('befinden', 78),
#  ('risiko', 78),
#  ('frei', 78),
#  ('sparkonto', 78),
#  ('erheben', 78),
#  ('didibank_bank', 78),
#  ('derzeit', 77),
#  ('garantieren', 77),
#  ('eröffnung', 77),
#  ('nehmen', 77),
#  ('wie_hoch_sein', 77),
#  ('grund', 77),
#  ('etf', 76),
#  ('persönlich_datum', 76),
#  ('rückzahlung', 76),
#  ('absichern', 76),
#  ('bearbeiten', 75),
#  ('zugreifen', 75),
#  ('widerrufen', 75),
#  ('gleich', 75),
#  ('kind', 75),
#  ('mobiletan', 74),
#  ('selbstverständlich', 74),
#  ('anlage', 74),
#  ('raten', 74),
#  ('anliegen', 74),
#  ('anleihe', 74),
#  ('abschluss', 74),
#  ('forderung', 74),
#  ('kreditnehmer', 74),
#  ('dividende', 74),
#  ('erkennen', 73),
#  ('hierbei', 73),
#  ('programm', 73),
#  ('ratenkredit', 73),
#  ('verlangen', 73),
#  ('onlinebanking', 73),
#  ('bevor', 72),
#  ('verwendung', 72),
#  ('benutzen', 72),
#  ('ausführen', 72),
#  ('abfragen', 72),
#  ('kapitalertrag', 72),
#  ('mobil', 71),
#  ('umgehen', 71),
#  ('passieren_wenn', 71),
#  ('einzeln', 71),
#  ('wünschen', 71),
#  ('mobilfunknummer', 71),
#  ('jährlich', 71),
#  ('mitglied', 71),
#  ('weitere', 70),
#  ('abheben', 70),
#  ('erfahren', 70),
#  ('schick', 70),
#  ('kopie', 70),
#  ('lang', 70),
#  ('visa', 70),
#  ('gutgeschrieben', 70),
#  ('geschäft', 69),
#  ('anbieter', 69),
#  ('eingehen', 69),
#  ('verlust', 69),
#  ('digipass', 69),
#  ('tan-verfahren', 68),
#  ('aktiv', 68),
#  ('übersicht', 68),
#  ('währung', 68),
#  ('versand', 68),
#  ('einkaufen', 68),
#  ('summe', 68),
#  ('durchführen', 67),
#  ('eventuell', 67),
#  ('korrekt', 67),
#  ('cookies', 67),
#  ('postident', 67),
#  ('nennen', 67),
#  ('partner', 67),
#  ('mandat', 67),
#  ('bereiten', 67),
#  ('tagesgeld', 67),
#  ('kontaktlos', 67),
#  ('gesetzlich_vertreter', 67),
#  ('deutsche_bank', 67),
#  ('erfolgreich', 66),
#  ('handeln_um', 66),
#  ('einrichtung', 66),
#  ('im_fallen', 66),
#  ('kontaktieren', 66),
#  ('anzahl', 66),
#  ('sepa', 66),
#  ('dispokredit', 66),
#  ('option', 66),
#  ('legen', 66),
#  ('finanzieren', 66),
#  ('betriebssystem', 65),
#  ('verbinden', 65),
#  ('häufig', 65),
#  ('folgen', 65),
#  ('verschlüsseln', 65),
#  ('schutz', 65),
#  ('pin_tan', 65),
#  ('nachweisen', 65),
#  ('identifizieren', 65),
#  ('entstehen', 65),
#  ('einzahlung', 65),
#  ('heißen', 65),
#  ('ausgeben', 65),
#  ('telefon-banking', 65),
#  ('gemeinschaftskonto', 65),
#  ('detail', 64),
#  ('postfach', 64),
#  ('wohnen', 64),
#  ('woche', 64),
#  ('dauern', 64),
#  ('aktualisieren', 64),
#  ('inklusive', 64),
#  ('abrufen', 63),
#  ('am_geldautomat', 63),
#  ('vollmacht', 63),
#  ('preisen', 63),
#  ('bestellung', 63),
#  ('tatsächlich', 63),
#  ('gleichen', 63),
#  ('schuldner', 63),
#  ('je', 63),
#  ('verlieren', 62),
#  ('auswahl', 62),
#  ('freigeben', 62),
#  ('auf_seite', 62),
#  ('anrufen', 62),
#  ('schreiben', 62),
#  ('besonders', 62),
#  ('erste', 62),
#  ('aufnehmen', 62),
#  ('position', 62),
#  ('voraussetzung_für', 61),
#  ('bisherig', 61),
#  ('hinzufügen', 61),
#  ('button', 61),
#  ('pdf', 61),
#  ('e-mail-adresse', 61),
#  ('steuerlich', 61),
#  ('wahl', 61),
#  ('finanzamt', 61),
#  ('e-rechnung', 61),
#  ('gelingen', 60),
#  ('anzeige', 60),
#  ('zertifikat', 60),
#  ('ausdrucken', 60),
#  ('wie_lang', 60),
#  ('code', 60),
#  ('frist', 60),
#  ('helfen', 60),
#  ('feld', 60),
#  ('smartphone_tablet', 59),
#  ('beantragung', 59),
#  ('2', 59),
#  ('berater', 59),
#  ('kundenservice', 59),
#  ('identität', 59),
#  ('bankverbindung', 59),
#  ('öffentlich', 59),
#  ('an_geldautomat', 59),
#  ('gebühren', 59),
#  ('ebics', 59),
#  ('abbuchen', 59),
#  ('arbeitgeber', 59),
#  ('zurückzahlen', 59),
#  ('zinsertrag', 59),
#  ('gleichzeitig', 58),
#  ('standard', 58),
#  ('gegenüber', 58),
#  ('zahlungsempfänger', 58),
#  ('ausführen_werden', 58),
#  ('menüpunkt', 58),
#  ('masterpass', 58),
#  ('schnell', 58),
#  ('leistung', 58),
#  ('beliebig', 58),
#  ('insgesamt', 58),
#  ('dritte', 58),
#  ('bei_didi_direct', 58),
#  ('aktivierung', 57),
#  ('anfragen', 57),
#  ('3', 57),
#  ('minute', 57),
#  ('umbuchung', 57),
#  ('unterscheiden', 57),
#  ('gutschrift', 57),
#  ('scheck', 57),
#  ('laufen', 57),
#  ('börse', 57),
#  ('etwa', 57),
#  ('lesegerät', 57),
#  ('internet', 56),
#  ('stelle', 56),
#  ('anforderung', 56),
#  ('verhindern', 56),
#  ('nutzer', 56),
#  ('telefonnummer', 56),
#  ('freigeschaltet', 56),
#  ('insbesondere', 56),
#  ('etc.', 56),
#  ('einstellen', 56),
#  ('versuchen', 56),
#  ('bedeuten_dass', 56),
#  ('auf_wunsch', 56),
#  ('ausführung', 56),
#  ('dispositionskredit', 56),
#  ('kreditantrag', 56),
#  ('international', 56),
#  ('beginnen', 55),
#  ('chiptan', 55),
#  ('banking-app', 55),
#  ('kontakt', 55),
#  ('zukünftig', 55),
#  ('nur_noch', 55),
#  ('für_minderjährig', 55),
#  ('ausreichen', 55),
#  ('vereinbaren', 55),
#  ('ganz_einfach', 55),
#  ('davon', 55),
#  ('pfändung', 55),
#  ('baufinanzierung', 55),
#  ('abgeltungsteuer', 55),
#  ('abwickeln', 55),
#  ('bankkonto', 54),
#  ('auskunft', 54),
#  ('gewährleisten', 54),
#  ('post', 54),
#  ('schaden', 54),
#  ('investieren', 54),
#  ('institut', 54),
#  ('staat', 54),
#  ('schreiten', 54),
#  ('niedrig', 54),
#  ('anschließend', 54),
#  ('sogar', 54),
#  ('stets', 54),
#  ('meist', 54),
#  ('anteil', 54),
#  ('kreditsumme', 54),
#  ('aktivierungscode', 54),
#  ('turbo', 54),
#  ('ausschließen', 53),
#  ('mobiletan-verfahren', 53),
#  ('außerhalb', 53),
#  ('schritt', 53),
#  ('technisch', 53),
#  ('zuständig', 53),
#  ('besitzen', 53),
#  ('während_laufzeit', 53),
#  ('auf_website', 53),
#  ('sparen', 53),
#  ('leisten', 53),
#  ('jahressteuerbescheinigung', 53),
#  ('profitieren', 53),
#  ('e-banking', 53),
#  ('starten', 52),
#  ('feststellen', 52),
#  ('postident-verfahren', 52),
#  ('secureapp', 52),
#  ('verfügung', 52),
#  ('europäisch', 52),
#  ('e-mails', 52),
#  ('weitere_information', 52),
#  ('kontaktlos_bezahlen', 52),
#  ('angabe', 52),
#  ('monatliche', 52),
#  ('tan-generator', 52),
#  ('verified_by_visa', 52),
#  ('freibetrag', 52),
#  ('sparcard', 52),
#  ('sollzins', 52),
#  ('konto-sms-service', 52),
#  ('punkt', 51),
#  ('beenden', 51),
#  ('verändern', 51),
#  ('per_sms', 51),
#  ('geschäftskunde', 51),
#  ('legitimation', 51),
#  ('in_land', 51),
#  ('bedingung', 51),
#  ('darauf', 51),
#  ('besonder', 51),
#  ('verbraucher', 51),
#  ('plus', 51),
#  ('sparbuch', 51),
#  ('keytrade_id', 51),
#  ('manuell', 50),
#  ('freischaltung', 50),
#  ('möchten', 50),
#  ('als_kunde', 50),
#  ('zielen', 50),
#  ('anpassen', 50),
#  ('natürlich_person', 50),
#  ('bis_zum', 50),
#  ('herunterladen', 50),
#  ('einziehen', 50),
#  ('klicken_auf', 50),
#  ('heute', 50),
#  ('berechnung', 50),
#  ('sondertilgung', 50),
#  ('allgemein', 49),
#  ('niemals', 49),
#  ('digital', 49),
#  ('so_genannt', 49),
#  ('inhaber', 49),
#  ('bereich', 49),
#  ('voll', 49),
#  ('erledigen', 49),
#  ('passieren', 49),
#  ('innerhalb_von', 49),
#  ('termin', 49),
#  ('wissen', 49),
#  ('trotzdem', 49),
#  ('zwar', 49),
#  ('in_anspruch_nehmen', 49),
#  ('ins', 49),
#  ('eingeräumt_kontoüberziehung_dispo', 49),
#  ('didibank_kreditkarte', 49),
#  ('keyplan', 49),
#  ('zusammen_mit', 48),
#  ('vergessen', 48),
#  ('angegeben', 48),
#  ('geldanlage', 48),
#  ('phone', 48),
#  ('anlagebetrag', 48),
#  ('beziehen', 48),
#  ('zeitpunkt', 48),
#  ('steuer', 48),
#  ('maestro-card', 48),
#  ('pushtan', 47),
#  ('s-pushtan-app', 47),
#  ('wenden_bitte_an', 47),
#  ('kontostand', 47),
#  ('anwendung', 47),
#  ('wunsch', 47),
#  ('zahlungsverkehr', 47),
#  ('zweck', 47),
#  ('januar', 47),
#  ('bis_uhr', 47),
#  ('verwaltung', 47),
#  ('unter_url', 47),
#  ('positiv', 47),
#  ('tipp', 47),
#  ('flexibel', 47),
#  ('ausgewählt', 47),
#  ('pushtan-verfahren', 46),
#  ('auf_pc', 46),
#  ('ausfahren', 46),
#  ('lässt', 46),
#  ('gern', 46),
#  ('gesetz', 46),
#  ('personalausweis', 46),
#  ('bekennen', 46),
#  ('zeigen', 46),
#  ('ausländisch', 46),
#  ('abrechnung', 46),
#  ('karteninhaber', 46),
#  ('falls', 46),
#  ('separat', 46),
#  ('ermitteln', 46),
#  ('gehören', 46),
#  ('buchen', 46),
#  ('maestro-bankomatkarte', 46),
#  ('verimi', 46),
#  ('zweit', 45),
#  ('einsatz', 45),
#  ('gmbh', 45),
#  ('zur_verfügung_stellen', 45),
#  ('belasten', 45),
#  ('bis_zur', 45),
#  ('hat', 45),
#  ('ausstellen', 45),
#  ('wirtschaftlich', 45),
#  ('handy', 45),
#  ('freischalten', 45),
#  ('aber_auch', 45),
#  ('allein', 45),
#  ('deaktivieren', 45),
#  ('dennoch', 45),
#  ('eignen', 45),
#  ('eg', 45),
#  ('teilnehmen', 45),
#  ('betrüger', 45),
#  ('erzeugen', 44),
#  ('android', 44),
#  ('gemäß', 44),
#  ('information_zu', 44),
#  ('gültigkeit', 44),
#  ('links', 44),
#  ('im_jahr', 44),
#  ('identifizierung', 44),
#  ('bisher', 44),
#  ('weiterleiten', 44),
#  ('malen', 44),
#  ('vermeiden', 44),
#  ('wesentlich', 44),
#  ('sprechen', 44),
#  ('ansicht', 44),
#  ('kreditgeber', 44),
#  ('kreditvertrag', 44),
#  ('kontoführung', 44),
#  ('didi_bank_direkt', 44),
#  ('didi_bank_ebanking', 44),
#  ('chiptan-verfahren', 43),
#  ('angezeigt', 43),
#  ('telefon', 43),
#  ('konto_eröffnen', 43),
#  ('ablehnen', 43),
#  ('geschehen', 43),
#  ('leider', 43),
#  ('regelung', 43),
#  ('chip', 43),
#  ('zahl', 43),
#  ('fest', 43),
#  ('beratung', 43),
#  ('offen', 43),
#  ('neu_karten', 43),
#  ('durchführen_werden', 43),
#  ('klein', 43),
#  ('markt', 43),
#  ('gründen', 43),
#  ('festgelegt', 43),
#  ('bausparvertrag', 43),
#  ('art', 43),
#  ('betreffen', 43),
#  ('vorgang', 43),
#  ('didiapp', 43),
#  ('didibank_poltawien', 43),
#  ('zurücksetzen', 42),
#  ('brief', 42),
#  ('langen', 42),
#  ('vorsehen', 42),
#  ('im_bereich', 42),
#  ('guthaben_auf', 42),
#  ('iban_bic', 42),
#  ('anhand', 42),
#  ('hören', 42),
#  ('solange', 42),
#  ('enden', 42),
#  ('website', 42),
#  ('bezahlvorgang', 42),
#  ('fenster', 42),
#  ('rahmenkredit', 42),
#  ('verfügungsrahmen', 42),
#  ('portfolio', 42),
#  ('online-konto', 42),
#  ('de-mail', 42),
#  ('definieren', 41),
#  ('können_tun_wenn', 41),
#  ('erfassen', 41),
#  ('ab_version', 41),
#  ('entwickeln', 41),
#  ('prüfen_ob', 41),
#  ('abwicklung', 41),
#  ('richten', 41),
#  ('zeichen', 41),
#  ('sperre', 41),
#  ('anspruch', 41),
#  ('stunde', 41),
#  ('online-brokerage', 41),
#  ('sonstig', 41),
#  ('finanziell', 41),
#  ('reduzieren', 41),
#  ('beinhalten', 41),
#  ('entnehmen', 41),
#  ('darstellen', 41),
#  ('fällig', 41),
#  ('gerade', 41),
#  ('rate', 41),
#  ('ablösen', 41),
#  ('hinweisen', 40),
#  ('symbol', 40),
#  ('übertragung', 40),
#  ('benutzerkennung', 40),
#  ('fremd', 40),
#  ('auf_basis', 40),
#  ('möglichst', 40),
#  ('beauftragen', 40),
#  ('regeln', 40),
#  ('ergeben', 40),
#  ('anschrift', 40),
#  ('preisverzeichnis_leistungsverzeichnis', 40),
#  ('email', 40),
#  ('schulde', 40),
#  ('trojaner', 40),
#  ('pfändungsschutzkonto', 40),
#  ('speziell', 40),
#  ('hilfe', 39),
#  ('sparkasse', 39),
#  ('gewählt', 39),
#  ('aufladen', 39),
#  ('netbank', 39),
#  ('annehmen', 39),
#  ('meldung', 39),
#  ('leiten', 39),
#  ('bezüglich', 39),
#  ('terminal', 39),
#  ('begrenzen', 39),
#  ('hier_finden', 39),
#  ('vermögen', 39),
#  ('rendite', 39),
#  ...]

# %%
model.most_similar('v_pay',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('bargeldverfügungen', 0.3114747107028961),
#  ('euro-transaktionen', 0.3073156177997589),
#  ('fachhandel', 0.30305615067481995),
#  ('ideen-center', 0.2905368506908417),
#  ('automatenbetreibern', 0.28749728202819824),
#  ('müller', 0.2874932587146759),
#  ('center', 0.2822272777557373),
#  ('geldkarten-chip', 0.2811480462551117),
#  ('konform', 0.27903151512145996),
#  ('españa', 0.27759188413619995),
#  ('paket', 0.26905369758605957),
#  ('gold', 0.2674068808555603),
#  ('kontaktlos_didibank_kreditkarte', 0.2649805247783661),
#  ('außenwirtschaftsverkehr', 0.26213106513023376),
#  ('plus-konto', 0.26194673776626587),
#  ('kartenausgebende', 0.2617916464805603),
#  ('inländische', 0.2551482319831848),
#  ('paywave', 0.255096971988678),
#  ('bepreist', 0.2545933425426483),
#  ('premium-karte', 0.2545696496963501),
#  ('schutzprogramme', 0.251840204000473),
#  ('auslandseinsatzentgelt', 0.24871431291103363),
#  ('starter-konto', 0.2478865534067154),
#  ('australien', 0.24491705000400543),
#  ('karten-pin', 0.2429025024175644),
#  ('transparent', 0.2417648583650589),
#  ('gründungsurkunde', 0.24121372401714325),
#  ('existenzgründer', 0.2398761659860611),
#  ('pin-brief', 0.23977065086364746),
#  ('meldebestätigung', 0.23884539306163788),
#  ('tool', 0.23864763975143433),
#  ('türkei', 0.2380719631910324),
#  ('erreichbarkeit', 0.237587571144104),
#  ('wohnung', 0.2374131679534912),
#  ('aufführen', 0.23729273676872253),
#  ('kontaktlos_zahlung', 0.23688733577728271),
#  ('bestandteil', 0.23597292602062225),
#  ('mietkautionsbürgschaft', 0.2355850487947464),
#  ('versehen', 0.23461230099201202),
#  ('fertig', 0.2342556267976761),
#  ('probezeit', 0.23262327909469604),
#  ('einkaufen', 0.2290753424167633),
#  ('geschäftsverkehr', 0.22832399606704712),
#  ('ausgewiesen', 0.22799688577651978),
#  ('hbci-verfahren', 0.22649171948432922),
#  ('höchstgrenze', 0.22605741024017334),
#  ('filialsuche', 0.2256973534822464),
#  ('bundeszentralamts', 0.2253526896238327),
#  ('didi_smartcard', 0.22530986368656158),
#  ('zinsmethode', 0.22372207045555115),
#  ('ansteigen', 0.22354911267757416),
#  ('mastercard-symbol', 0.22294075787067413),
#  ('ab_wann', 0.22236250340938568),
#  ('zinsbindung', 0.22158056497573853),
#  ('privatbank', 0.22132571041584015),
#  ('verified_by_visa_mastercard', 0.22031989693641663),
#  ('for', 0.21976685523986816),
#  ('maustaste', 0.21969860792160034),
#  ('automat', 0.21942749619483948),
#  ('kostenlos_bargeld', 0.21923255920410156),
#  ('bonusprogramm', 0.21845737099647522),
#  ('kartenprüfnummer', 0.21820694208145142),
#  ('kostenlos_bargeld_abheben', 0.2181250900030136),
#  ('dienstag', 0.21640725433826447),
#  ('emv-chip', 0.21550588309764862),
#  ('notfalls', 0.2155047357082367),
#  ('anlagethemen', 0.21535810828208923),
#  ('pro_jahr', 0.2147282361984253),
#  ('apple_pay', 0.21464434266090393),
#  ('online-zugang', 0.21451054513454437),
#  ('mastercard-logo', 0.2144622504711151),
#  ('raum', 0.2143404483795166),
#  ('mittlerweile', 0.21333862841129303),
#  ('bewirken', 0.213148295879364),
#  ('einzelhandel', 0.21309363842010498),
#  ('komfort-konto', 0.21263478696346283),
#  ('didieasy', 0.21249307692050934),
#  ('günstige', 0.21215711534023285),
#  ('lizenz', 0.21187350153923035),
#  ('zahlungsschwierigkeiten', 0.21186108887195587),
#  ('voraus', 0.21099300682544708),
#  ('sitz', 0.2103097140789032),
#  ('touch-id', 0.21007783710956573),
#  ('geldsumme', 0.20965155959129333),
#  ('rote', 0.2090710550546646),
#  ('feste', 0.20890964567661285),
#  ('wertstellungsdatum', 0.20870134234428406),
#  ('vorsorgen', 0.20847418904304504),
#  ('einsicht', 0.20773938298225403),
#  ('am_automat', 0.20763146877288818),
#  ('geprüft', 0.2074839174747467),
#  ('norwegen', 0.20730747282505035),
#  ('goldcard', 0.2072402536869049),
#  ('bürgschaft', 0.20716433227062225),
#  ('vr-securecard-app', 0.20662003755569458),
#  ('urlaub', 0.20514565706253052),
#  ('kontakt', 0.20472511649131775),
#  ('geschäftsbanken', 0.20418857038021088),
#  ('umsatzanzeige', 0.20361655950546265),
#  ('spanien', 0.2035956233739853)]

# %%
model.most_similar('3d_secure',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('mastercard_securecode', 0.2488345503807068),
#  ('verified_by_visa', 0.24692432582378387),
#  ('entschädigungsanspruch', 0.23524144291877747),
#  ('wkn', 0.22715741395950317),
#  ('3d-secure', 0.22095055878162384),
#  ('mybankingapp', 0.22018495202064514),
#  ('steuern', 0.21706195175647736),
#  ('planungssicherheit', 0.21326054632663727),
#  ('sicherheitscode', 0.21233093738555908),
#  ('mastercard_®_securecodetm', 0.20867282152175903),
#  ('pharming', 0.20851606130599976),
#  ('abbrechen', 0.20825934410095215),
#  ('3d', 0.20711691677570343),
#  ('24h-kundenservice', 0.20466722548007965),
#  ('banking-app', 0.20455235242843628),
#  ('eigenkapitalanteil', 0.20365478098392487),
#  ('girocard_kontaktlos', 0.20295622944831848),
#  ('absender', 0.1975666731595993),
#  ('umfassen', 0.19717350602149963),
#  ('emv-chip', 0.19629788398742676),
#  ('sumup', 0.19627642631530762),
#  ('mobile-banking', 0.19615301489830017),
#  ('day-trading', 0.19481110572814941),
#  ('minderjährig', 0.1947644054889679),
#  ('international', 0.19354255497455597),
#  ('heimatnetz', 0.19349917769432068),
#  ('sicherheitsabfrage', 0.19293881952762604),
#  ('offline-version', 0.1926604062318802),
#  ('freibetrag', 0.19139248132705688),
#  ('mastercard_®', 0.1905304491519928),
#  ('giro_basis', 0.1900254189968109),
#  ('online-version', 0.1895837038755417),
#  ('finanzdienstleister', 0.18904833495616913),
#  ('de-mail-anbieter', 0.1878761202096939),
#  ('umbau', 0.1874018907546997),
#  ('equiduct', 0.1864762306213379),
#  ('tanken', 0.18550041317939758),
#  ('richtlinie', 0.18468248844146729),
#  ('ergänzend', 0.18359506130218506),
#  ('plus-verfahren', 0.18308863043785095),
#  ('didi_bank_ebanking', 0.18294145166873932),
#  ('vertragsbedingungen', 0.1809575855731964),
#  ('insoweit', 0.18089494109153748),
#  ('einspruch', 0.18061619997024536),
#  ('förderdarlehen', 0.18060986697673798),
#  ('pari', 0.1800752878189087),
#  ('frage_wenden', 0.17769014835357666),
#  ('berechtigter', 0.17757676541805267),
#  ('kurzmitteilungen', 0.17724019289016724),
#  ('kontaktlos_bezahlen_mit', 0.17721249163150787),
#  ('bürgschaft', 0.17677821218967438),
#  ('berechnung', 0.17623980343341827),
#  ('sparplan', 0.17527689039707184),
#  ('planung', 0.17511267960071564),
#  ('ing-diba', 0.1748262494802475),
#  ('alleinstehend', 0.17472410202026367),
#  ('verkaufsauftrag', 0.17468228936195374),
#  ('®_securecode_™', 0.17464911937713623),
#  ('secureapp', 0.17409172654151917),
#  ('shortpin', 0.17391067743301392),
#  ('energiesperre', 0.1738663613796234),
#  ('ambibank_online-banking', 0.1738063097000122),
#  ('securecode', 0.1736440807580948),
#  ('kundendialog', 0.1734214425086975),
#  ('erlassen', 0.17336724698543549),
#  ('kontaktlos_zahlung', 0.17192471027374268),
#  ('debit_mastercard', 0.17189188301563263),
#  ('starke', 0.1718498170375824),
#  ('aktiv', 0.17129181325435638),
#  ('englische', 0.17125673592090607),
#  ('optimieren', 0.17096500098705292),
#  ('stiftung', 0.17093616724014282),
#  ('vertragsinhaber', 0.17091156542301178),
#  ('pfändungsfreibetrag', 0.17067885398864746),
#  ('zahlungsdienst', 0.17064820230007172),
#  ('bequem', 0.16941826045513153),
#  ('lastschriftverfahren', 0.1691359132528305),
#  ('gebrauchtwagen', 0.16851691901683807),
#  ('nie', 0.16700607538223267),
#  ('kündigungswunsch', 0.16662831604480743),
#  ('wertpapiertransaktionen', 0.16587623953819275),
#  ('effizient', 0.1658012568950653),
#  ('secure', 0.16573722660541534),
#  ('nennwert', 0.16573457419872284),
#  ('schadsoftware', 0.16504664719104767),
#  ('neu_gerät', 0.164802685379982),
#  ('niw', 0.164509117603302),
#  ('cookie', 0.1644885241985321),
#  ('otp', 0.16438858211040497),
#  ('eingabefenster', 0.16432581841945648),
#  ('kauf', 0.16416873037815094),
#  ('transaktionsnummer', 0.16410233080387115),
#  ('scheck', 0.1640000343322754),
#  ('extra', 0.16399811208248138),
#  ('maßnahme', 0.16399718821048737),
#  ('baugeld', 0.16399645805358887),
#  ('sicher_persönlich_identifikation', 0.16383607685565948),
#  ('worldwide', 0.16365832090377808),
#  ('zugriffen', 0.16298294067382812),
#  ('servicebereich', 0.162892147898674)]

# %%
model.most_similar('überweisung',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('neu_karten', 0.23287352919578552),
#  ('vollmacht', 0.23170696198940277),
#  ('ordern', 0.22963351011276245),
#  ('umbuchung', 0.2246394008398056),
#  ('zahlungseingang', 0.21919173002243042),
#  ('kreditantrag', 0.2169725000858307),
#  ('karten', 0.21559135615825653),
#  ('zahlung', 0.2152094841003418),
#  ('auslandsüberweisungen', 0.20904403924942017),
#  ('vorschlag', 0.20758584141731262),
#  ('geschäftskonto', 0.20660938322544098),
#  ('umbuchen', 0.20394685864448547),
#  ('dienstleistung', 0.2019285261631012),
#  ('verfügung', 0.20145510137081146),
#  ('antragstellung', 0.20120415091514587),
#  ('profil', 0.19920650124549866),
#  ('ursache', 0.1964338719844818),
#  ('cookies', 0.19570493698120117),
#  ('geschäftstag', 0.19205674529075623),
#  ('oglietzener', 0.19107523560523987),
#  ('woche', 0.19020941853523254),
#  ('registrierung', 0.187086820602417),
#  ('hinterlegung', 0.18617986142635345),
#  ('bankfilialen', 0.1858333796262741),
#  ('umsatzübersicht', 0.18360687792301178),
#  ('bis_maximal', 0.18207848072052002),
#  ('ausnehmen', 0.1818549633026123),
#  ('identität', 0.1818057745695114),
#  ('auftrag', 0.18081004917621613),
#  ('neuemissionen', 0.1802884042263031),
#  ('transaktion', 0.18027634918689728),
#  ('automatisieren', 0.17786698043346405),
#  ('januar', 0.17734473943710327),
#  ('handelspartner', 0.1771412193775177),
#  ('extern', 0.17706124484539032),
#  ('vermieter', 0.17697332799434662),
#  ('offline-version', 0.1765589714050293),
#  ('zutreffen', 0.176353320479393),
#  ('aufstellung', 0.1756865680217743),
#  ('kennwort', 0.17567965388298035),
#  ('bestandskunden', 0.17396266758441925),
#  ('genossenschaft', 0.17387935519218445),
#  ('einrichtung', 0.17387282848358154),
#  ('kassenterminal', 0.1720784306526184),
#  ('kontinuierlich', 0.17118428647518158),
#  ('missbräuchliche', 0.17108409106731415),
#  ('sammellastschrift', 0.17050741612911224),
#  ('bargeldbehebung', 0.1691858172416687),
#  ('einkauf', 0.16913464665412903),
#  ('beruhen', 0.167493537068367),
#  ('zur_gutschrift', 0.1672048717737198),
#  ('didisparkonto', 0.1661316454410553),
#  ('vertragspartner', 0.1659451723098755),
#  ('wöchentlich', 0.16413670778274536),
#  ('ändern', 0.16362334787845612),
#  ('abweichung', 0.16305981576442719),
#  ('sollzinsbindung', 0.16299869120121002),
#  ('telefonnummern', 0.16298134624958038),
#  ('auszahlung', 0.16293926537036896),
#  ('einholung', 0.16291236877441406),
#  ('ohg', 0.16287977993488312),
#  ('inländische', 0.16204260289669037),
#  ('buchung', 0.16203339397907257),
#  ('buchungstag', 0.16185608506202698),
#  ('rechtmäßig_karteninhaber', 0.16110941767692566),
#  ('einlagensicherung', 0.16097359359264374),
#  ('schwankung', 0.1609288454055786),
#  ('solaris', 0.16060909628868103),
#  ('energiesperre', 0.16058297455310822),
#  ('feedback', 0.1605166792869568),
#  ('aufladung', 0.1601063758134842),
#  ('deutlich', 0.15972115099430084),
#  ('referenzwert', 0.15914344787597656),
#  ('terminüberweisung', 0.15861457586288452),
#  ('nutzer', 0.15857017040252686),
#  ('betriebssystem', 0.1584566980600357),
#  ('eigen_sicherheit', 0.15837231278419495),
#  ('spätestens', 0.1573033481836319),
#  ('schaden', 0.15728354454040527),
#  ('über_kontaktformular', 0.157282292842865),
#  ('freischalten', 0.15690241754055023),
#  ('freistellungsauftrag', 0.15689264237880707),
#  ('online-legitimation', 0.15583691000938416),
#  ('code', 0.1550147831439972),
#  ('schadsoftware', 0.1547788828611374),
#  ('einzahlung', 0.1547478586435318),
#  ('unix-betriebssystemen', 0.15422406792640686),
#  ('reisepasses', 0.15417350828647614),
#  ('fragen', 0.1539146453142166),
#  ('kunde', 0.15322048962116241),
#  ('pin', 0.15281468629837036),
#  ('steuerberater', 0.1524210423231125),
#  ('einnahmen', 0.15194301307201385),
#  ('erforderlich_unterliegen', 0.15191593766212463),
#  ('wort', 0.15158167481422424),
#  ('sehr', 0.15113823115825653),
#  ('partnershop', 0.15094542503356934),
#  ('steuer-id', 0.15047717094421387),
#  ('zugelassen', 0.15038512647151947),
#  ('arbeitstagen', 0.15019387006759644)]

# %%
model.most_similar('baukredit',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('im_vorfeld', 0.32634103298187256),
#  ('nachfinanzierungen', 0.2807047665119171),
#  ('kundenservices', 0.27784159779548645),
#  ('privatkredit', 0.27301928400993347),
#  ('worauf', 0.27000877261161804),
#  ('de_nederlandsche', 0.26389721035957336),
#  ('beilegen', 0.26159584522247314),
#  ('rahmenkredits', 0.25842171907424927),
#  ('in_rechnung_stellen', 0.25045931339263916),
#  ('feste', 0.24339979887008667),
#  ('einschätzung', 0.2433888167142868),
#  ('umschulden', 0.24166004359722137),
#  ('privatkunde_geschäftskunde', 0.24051202833652496),
#  ('bau', 0.23471470177173615),
#  ('didibank-girokonto', 0.22909697890281677),
#  ('löschung', 0.22904889285564423),
#  ('gestellt', 0.22898593544960022),
#  ('freistellen', 0.22548849880695343),
#  ('hypovereinsbank', 0.21971456706523895),
#  ('3d_secure_verfahren', 0.2195243537425995),
#  ('samt', 0.21867778897285461),
#  ('einbringen', 0.21631091833114624),
#  ('kontaktieren', 0.21623702347278595),
#  ('eingeräumt', 0.21542347967624664),
#  ('weiterhelfen', 0.21505293250083923),
#  ('online-banking-kunde', 0.21281833946704865),
#  ('freischaltcode', 0.21274352073669434),
#  ('per_e-mail_email', 0.21264943480491638),
#  ('marktgerecht', 0.2118796855211258),
#  ('mietverhältnis', 0.21185402572155),
#  ('informationstechnik', 0.2106306105852127),
#  ('kaufpreis', 0.20970435440540314),
#  ('schicken', 0.20963025093078613),
#  ('us-dollar', 0.20950216054916382),
#  ('fertigen', 0.20948539674282074),
#  ('finanzierung', 0.20853976905345917),
#  ('agieren', 0.20847190916538239),
#  ('kündigungsschreiben', 0.20668068528175354),
#  ('nebst', 0.20631547272205353),
#  ('bewahren', 0.20366962254047394),
#  ('baudarlehen', 0.20297163724899292),
#  ('empfangen', 0.20255815982818604),
#  ('besteht', 0.2019842267036438),
#  ('verwerten', 0.20151738822460175),
#  ('finden_unter_url', 0.20151643455028534),
#  ('tagen_vor', 0.20069554448127747),
#  ('auslaufen', 0.20063737034797668),
#  ('kunde', 0.20056544244289398),
#  ('einschätzen', 0.200308695435524),
#  ('lass', 0.1996745467185974),
#  ('öffnungszeit', 0.19933952391147614),
#  ('sicherungsverfahren', 0.19918325543403625),
#  ('aufsetzen', 0.19886384904384613),
#  ('wie_lang_dauern', 0.1980486363172531),
#  ('steuerabzug', 0.19740360975265503),
#  ('port', 0.19721025228500366),
#  ('darlehensgeber', 0.19678959250450134),
#  ('zahlungs', 0.19674651324748993),
#  ('echtzeit-kurse', 0.1967412829399109),
#  ('mitteile', 0.19605815410614014),
#  ('einfahren', 0.19603213667869568),
#  ('versicherungsleistungen', 0.19495591521263123),
#  ('aktive', 0.19427409768104553),
#  ('vollziehen', 0.19285213947296143),
#  ('wichtigste', 0.19255629181861877),
#  ('aufgelaufen', 0.19243532419204712),
#  ('exakt', 0.1919436901807785),
#  ('sage', 0.19139397144317627),
#  ('erwerbstätigkeit', 0.1902652531862259),
#  ('obligatorisch', 0.1899491399526596),
#  ('bewerten', 0.1898912787437439),
#  ('schriftgröße', 0.189083069562912),
#  ('didibank_ag_co._kgaa', 0.18852950632572174),
#  ('niederlassungserlaubnis', 0.18847398459911346),
#  ('steuer-identifikationsnummer', 0.18832947313785553),
#  ('online-überweisungen', 0.1883162260055542),
#  ('beeinflusst', 0.18817412853240967),
#  ('einzige', 0.18815931677818298),
#  ('kontoüberziehung', 0.188140407204628),
#  ('planmäßig', 0.18779869377613068),
#  ('pro-konto', 0.18771271407604218),
#  ('aufkommen', 0.18760453164577484),
#  ('verursachen', 0.1870517134666443),
#  ('online-formular', 0.18575237691402435),
#  ('tägliche', 0.1857345700263977),
#  ('juni', 0.18483754992485046),
#  ('reichen', 0.18439868092536926),
#  ('sicherheitseinstellungen', 0.18424710631370544),
#  ('aufenthaltsgenehmigung', 0.1836284101009369),
#  ('immobilienfinanzierung', 0.1820872277021408),
#  ('andernfalls', 0.18043607473373413),
#  ('einrichtung', 0.17985990643501282),
#  ('zur_auswahl', 0.1788415014743805),
#  ('auslandseinsatzentgelt', 0.17863287031650543),
#  ('zahlungskonto', 0.17855224013328552),
#  ('haftpflichtversicherung', 0.1783241182565689),
#  ('vl-sparvertrag', 0.17832352221012115),
#  ('mastercard_®', 0.17828774452209473),
#  ('sparen', 0.1778274029493332),
#  ('nachfinanzierung', 0.17774450778961182)]

# %%
model.most_similar('baufinanzierung',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('projekt', 0.2618786096572876),
#  ('weiterführend', 0.24957485496997833),
#  ('zwangsversteigerung', 0.24605101346969604),
#  ('solidaritätszuschlag', 0.24468612670898438),
#  ('extra-konto', 0.24428510665893555),
#  ('kreditrückzahlung', 0.2433900237083435),
#  ('begleiten', 0.2415502965450287),
#  ('gemeinschaftsdepot', 0.24135401844978333),
#  ('unfall', 0.2401580959558487),
#  ('broschüre', 0.23099735379219055),
#  ('kreditanfrage', 0.22698089480400085),
#  ('ratenschutz', 0.22634154558181763),
#  ('fahrzeug', 0.2237122654914856),
#  ('so_lang', 0.22311821579933167),
#  ('freistellungsauftrag_erteilen', 0.2176537811756134),
#  ('festlegung', 0.21510696411132812),
#  ('schufa', 0.2144240438938141),
#  ('umbau', 0.21435295045375824),
#  ('riester-förderung', 0.21049335598945618),
#  ('herabsetzen', 0.2098509669303894),
#  ('kontaktaufnahme', 0.20750293135643005),
#  ('top-girokonto', 0.20492881536483765),
#  ('girokonto', 0.20413489639759064),
#  ('ökokredit', 0.20350351929664612),
#  ('weiterentwickel', 0.20239640772342682),
#  ('niedrigzins-garantie', 0.20186468958854675),
#  ('premium-karten', 0.20022329688072205),
#  ('objekt', 0.1996593475341797),
#  ('im_ausland', 0.1995396614074707),
#  ('übrig', 0.19881995022296906),
#  ('trennen', 0.1967199146747589),
#  ('google', 0.1955852210521698),
#  ('frist', 0.1955762803554535),
#  ('renovierung', 0.19553661346435547),
#  ('löschungsbewilligung', 0.19514453411102295),
#  ('mieten', 0.19387294352054596),
#  ('insolvenz', 0.19344256818294525),
#  ('einholung', 0.19312898814678192),
#  ('zielkonto', 0.19300581514835358),
#  ('dispo-rahmenvereinbarung', 0.19185976684093475),
#  ('mastercard_kreditkarte', 0.19156527519226074),
#  ('im_todesfall', 0.19093811511993408),
#  ('einlösung', 0.19048450887203217),
#  ('betriebskosten', 0.18952231109142303),
#  ('l-bank', 0.18944746255874634),
#  ('eigenheim', 0.18931114673614502),
#  ('browsercache', 0.18792909383773804),
#  ('nutzer', 0.18781976401805878),
#  ('versionsnummer', 0.18761169910430908),
#  ('e-rechnung', 0.1876017451286316),
#  ('muß', 0.18759623169898987),
#  ('laufend_jahr', 0.1869971752166748),
#  ('gläubiger-id', 0.18660348653793335),
#  ('e.v.', 0.186113640666008),
#  ('bürgen', 0.1856706738471985),
#  ('eigenständige', 0.18539881706237793),
#  ('finanzierend', 0.1848674714565277),
#  ('sammelkonto', 0.18481725454330444),
#  ('arbeiten_kontinuierlich_an', 0.18473367393016815),
#  ('steuersatz', 0.18466369807720184),
#  ('empfängerdaten', 0.1845466047525406),
#  ('kennwort', 0.18447072803974152),
#  ('steuerbescheinigung', 0.18433448672294617),
#  ('menupunkt', 0.18411153554916382),
#  ('850k', 0.18350809812545776),
#  ('darlehenszinsen', 0.18305447697639465),
#  ('absichern', 0.18300089240074158),
#  ('bis_euro', 0.18242256343364716),
#  ('secure-authentifizierung', 0.18155153095722198),
#  ('wertpapierarten', 0.181500643491745),
#  ('datensicherheit', 0.18120700120925903),
#  ('chiptan-generator', 0.18111830949783325),
#  ('frage', 0.1801273375749588),
#  ('top-kredit', 0.17956505715847015),
#  ('veralten', 0.17912974953651428),
#  ('customer_care_center', 0.17878064513206482),
#  ('versicherungsbeitrag', 0.17877836525440216),
#  ('ordern', 0.17867238819599152),
#  ('mit_tan_bestätigen', 0.1779470145702362),
#  ('an_geldautomat_ander_banken', 0.1778576821088791),
#  ('mandatsreferenz', 0.17745822668075562),
#  ('erstellen', 0.17730307579040527),
#  ('ursache', 0.17712941765785217),
#  ('finanzdienstleistungsaufsicht', 0.17693467438220978),
#  ('auslandszahlung', 0.17598028481006622),
#  ('maximal_€', 0.17593057453632355),
#  ('umschulden', 0.17423085868358612),
#  ('änderung_mobilfunknummer', 0.17417892813682556),
#  ('mutter', 0.17366287112236023),
#  ('erforderlich_unterliegen', 0.17361915111541748),
#  ('per_brief', 0.17282475531101227),
#  ('versteuern', 0.17273126542568207),
#  ('verfügungslimit', 0.17247410118579865),
#  ('termin', 0.1723267287015915),
#  ('maestro', 0.1723184585571289),
#  ('zusatzversicherung', 0.17158812284469604),
#  ('phototan-app', 0.17046990990638733),
#  ('app_sparkasse_sparkasse+', 0.1703382283449173),
#  ('ausführungstag', 0.17020420730113983),
#  ('einrichtung', 0.17016556859016418)]

# %%
model.most_similar('schufa',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('ablösung', 0.22020521759986877),
#  ('baufinanzierung', 0.2144240438938141),
#  ('l-bank', 0.2062300145626068),
#  ('bewilligung', 0.20558935403823853),
#  ('finanz', 0.19377553462982178),
#  ('fertig', 0.19358618557453156),
#  ('zahlungsinformationen', 0.19339008629322052),
#  ('zugestellt', 0.1928931325674057),
#  ('§', 0.1909472644329071),
#  ('effektivzins', 0.18963374197483063),
#  ('securecode', 0.18658095598220825),
#  ('telefon-pin', 0.18393899500370026),
#  ('nähern', 0.1834266632795334),
#  ('online-kredit', 0.18299588561058044),
#  ('sicherheit', 0.18291731178760529),
#  ('entsprechend_formular', 0.1811772882938385),
#  ('filialbank', 0.18003517389297485),
#  ('postident', 0.17897388339042664),
#  ('secure', 0.1785837858915329),
#  ('jederzeit_möglich', 0.17775779962539673),
#  ('tradegate', 0.17765268683433533),
#  ('regeln', 0.1770571768283844),
#  ('six', 0.17556512355804443),
#  ('zuteilung', 0.17505817115306854),
#  ('unzutreffend', 0.17498120665550232),
#  ('disagio', 0.17434336245059967),
#  ('oglietzen_am_main', 0.1739174723625183),
#  ('noch_einmal', 0.1723831295967102),
#  ('privatbank', 0.17237593233585358),
#  ('downloads', 0.17206983268260956),
#  ('vorlage', 0.17117930948734283),
#  ('anklicken', 0.1708792746067047),
#  ('didipay', 0.17076094448566437),
#  ('anhängen', 0.17015232145786285),
#  ('urlaubsplus', 0.1692180186510086),
#  ('leasingobjekte', 0.1685389131307602),
#  ('kreditgeber', 0.16803371906280518),
#  ('orderbuch', 0.16793593764305115),
#  ('google_play', 0.1673302948474884),
#  ('vereinbart_laufzeit', 0.16632863879203796),
#  ('netbanking', 0.16577783226966858),
#  ('geschäftsstelle', 0.16549284756183624),
#  ('didi_bank_ag', 0.16513195633888245),
#  ('annullierung', 0.16450779139995575),
#  ('meldepflicht', 0.16441896557807922),
#  ('sicherheitsmerkmal', 0.164122074842453),
#  ('berechtigter', 0.16377609968185425),
#  ('legitim', 0.1637757569551468),
#  ('an_dritte', 0.16326041519641876),
#  ('neu_banking_brokerage', 0.16284418106079102),
#  ('zoin', 0.16261930763721466),
#  ('konto-sms-service', 0.16251786053180695),
#  ('guthabenkonto', 0.16228307783603668),
#  ('extra-konto', 0.16201557219028473),
#  ('pushtan-app', 0.1616874784231186),
#  ('schulde', 0.1613999456167221),
#  ('realtime-kurse', 0.16119727492332458),
#  ('sepa-lastschrift', 0.16111037135124207),
#  ('lösung', 0.16085292398929596),
#  ('erste', 0.16066186130046844),
#  ('zinskonditionen', 0.15982170403003693),
#  ('abgesehen', 0.15888968110084534),
#  ('ausloggen', 0.1582215279340744),
#  ('status', 0.15800324082374573),
#  ('darlehen', 0.15795555710792542),
#  ('höhe', 0.15719963610172272),
#  ('mastercard_securecode', 0.15712235867977142),
#  ('iban', 0.15691691637039185),
#  ('prepaid-pin', 0.156887948513031),
#  ('leasingratenversicherung', 0.1563628762960434),
#  ('payments', 0.15610024333000183),
#  ('baudarlehen', 0.15572741627693176),
#  ('i', 0.15549878776073456),
#  ('gezielt', 0.15464313328266144),
#  ('leasing-anfrage', 0.15446129441261292),
#  ('besonderheit', 0.15443305671215057),
#  ('einkommensnachweise', 0.15442898869514465),
#  ('direktkredit', 0.15402115881443024),
#  ('generator', 0.15380555391311646),
#  ('beamter', 0.15285782516002655),
#  ('servicecenter', 0.15273308753967285),
#  ('fehlerhaft', 0.15270251035690308),
#  ('browsercache', 0.15238989889621735),
#  ('standardauswahl', 0.1523095816373825),
#  ('restkreditversicherung', 0.15185770392417908),
#  ('dialog', 0.15164241194725037),
#  ('schuldnerberatungsstelle', 0.15126535296440125),
#  ('börsenschluss', 0.15107743442058563),
#  ('zurücküberweisen', 0.15081380307674408),
#  ('kreditarten', 0.1507432609796524),
#  ('genossenschaftsbanken', 0.15054835379123688),
#  ('dennoch', 0.15039363503456116),
#  ('arbeitsverhältnis', 0.14989647269248962),
#  ('lang_laufzeit', 0.14913047850131989),
#  ('im_online-banking-bereich', 0.14860716462135315),
#  ('tan-blocks', 0.14815494418144226),
#  ('bankfiliale', 0.1481504738330841),
#  ('communication', 0.14797477424144745),
#  ('aktivierungsbrief', 0.1479732096195221),
#  ('pensionär', 0.1469927877187729)]

# %%
model.most_similar('kreditkarte',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('vereinbarung', 0.3098123371601105),
#  ('karten', 0.2569924294948578),
#  ('didi_bankcard', 0.23060432076454163),
#  ('kontaktlos_didibank_kreditkarte', 0.2267434149980545),
#  ('boosten', 0.2151491641998291),
#  ('passwort', 0.20313039422035217),
#  ('dispokredit', 0.20145970582962036),
#  ('zusatzkarten', 0.20052531361579895),
#  ('profitieren_von', 0.200259730219841),
#  ('lass', 0.1998169720172882),
#  ('zahlungsanweisungen', 0.19966815412044525),
#  ('nach_registrierung', 0.19801215827465057),
#  ('kontoeröffnung', 0.19690361618995667),
#  ('maestro-bankomatkarte', 0.18901890516281128),
#  ('pin-eingabe', 0.18702182173728943),
#  ('kind', 0.1856168508529663),
#  ('buchung', 0.18512651324272156),
#  ('callcenter', 0.18260380625724792),
#  ('pushtan-verfahren', 0.18254207074642181),
#  ('dienstleistung', 0.17927226424217224),
#  ('ausserdem', 0.17758899927139282),
#  ('maestro-card', 0.1773354560136795),
#  ('element', 0.17709077894687653),
#  ('tool', 0.17636920511722565),
#  ('ausfüllen', 0.17584659159183502),
#  ('wphg', 0.17361417412757874),
#  ('heutig', 0.17337444424629211),
#  ('kreditgeber', 0.17302311956882477),
#  ('ausnahme', 0.17295317351818085),
#  ('einlösen', 0.1728634238243103),
#  ('unter', 0.17225977778434753),
#  ('richtlinie', 0.1720896065235138),
#  ('arbeitsplatz', 0.1706908941268921),
#  ('eingeräumt_kontoüberziehung_dispo', 0.1706644892692566),
#  ('software', 0.17032445967197418),
#  ('überweisung_dauerauftrag', 0.1698049008846283),
#  ('kreditbetrag', 0.16969361901283264),
#  ('unterhalten', 0.16901525855064392),
#  ('zinssatz', 0.16864430904388428),
#  ('täglich', 0.1685958355665207),
#  ('kapitalgesellschaft', 0.16818514466285706),
#  ('festgeld', 0.1681532859802246),
#  ('schildern', 0.16783453524112701),
#  ('betriebssystem', 0.16636411845684052),
#  ('15', 0.1659788340330124),
#  ('anmeldename', 0.1642749309539795),
#  ('möchten', 0.16408567130565643),
#  ('premium-karte', 0.16399137675762177),
#  ('heute', 0.1639297604560852),
#  ('zukommen', 0.16142946481704712),
#  ('mobiletan-service', 0.16042697429656982),
#  ('zugang', 0.16032837331295013),
#  ('ambibank_card_debitkarte', 0.16012129187583923),
#  ('webseiten', 0.15994897484779358),
#  ('ergänzung', 0.15947245061397552),
#  ('entladen', 0.15847410261631012),
#  ('zahlungsempfänger', 0.15793398022651672),
#  ('weiterleitung', 0.15790627896785736),
#  ('geschenkkarte', 0.1569696068763733),
#  ('partnershop', 0.15678337216377258),
#  ('anmeldename_legitimations-id', 0.1565442830324173),
#  ('kreditentscheidung', 0.15580755472183228),
#  ('visacard', 0.15459318459033966),
#  ('verstoßen', 0.15363700687885284),
#  ('gleichen', 0.15341995656490326),
#  ('fernabsatzgesetz', 0.1522987335920334),
#  ('mastercard_karten', 0.15225860476493835),
#  ('befreiung', 0.1517837941646576),
#  ('servicezeiten', 0.15176281332969666),
#  ('luxemburg', 0.15173496305942535),
#  ('abrechnen', 0.15159618854522705),
#  ('paydirekt', 0.15153288841247559),
#  ('unterbuchung', 0.1515303999185562),
#  ('im_internetbanking', 0.15114326775074005),
#  ('genialcard', 0.15085932612419128),
#  ('gerät', 0.15066680312156677),
#  ('privatkredit', 0.14916713535785675),
#  ('technische', 0.14916621148586273),
#  ('nämlich', 0.14895372092723846),
#  ('überweisung', 0.1488438993692398),
#  ('vorsichtig', 0.14879602193832397),
#  ('kaufen', 0.14753256738185883),
#  ('mein_dass', 0.14723514020442963),
#  ('eigentümerdarlehen', 0.14719898998737335),
#  ('didionline-banking', 0.14702339470386505),
#  ('kreditunterlagen', 0.1469089239835739),
#  ('beraterin', 0.14688387513160706),
#  ('bei_teilnehmend', 0.14685557782649994),
#  ('sichertasche', 0.14522475004196167),
#  ('shortpin', 0.14510765671730042),
#  ('bemühung', 0.14489716291427612),
#  ('luxemburgische', 0.1448662132024765),
#  ('einzug', 0.14411960542201996),
#  ('vorfälligkeitsentschädigung', 0.1436944454908371),
#  ('sms', 0.1434776932001114),
#  ('schlosssymbol', 0.14330048859119415),
#  ('überprüfung', 0.14320312440395355),
#  ('gerichtsvollzieher', 0.1431693285703659),
#  ('zoin-funktion', 0.14316624402999878),
#  ('konto-sofortcheck', 0.1431448608636856)]

# %%
model.most_similar('freistellungsauftrag',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('antrag', 0.24875222146511078),
#  ('leasing-anfrage', 0.24268631637096405),
#  ('verkaufsauftrag', 0.23540721833705902),
#  ('befreiung', 0.2307724803686142),
#  ('postident-verfahren', 0.22407454252243042),
#  ('investieren', 0.22367995977401733),
#  ('geschäftstag', 0.2235681116580963),
#  ('zurückgehen', 0.2151111215353012),
#  ('zutreffen', 0.20851799845695496),
#  ('prepaid-karte', 0.20719696581363678),
#  ('zertifikat', 0.20635633170604706),
#  ('vertrag', 0.20347079634666443),
#  ('umziehen', 0.20096249878406525),
#  ('genialcard', 0.19802580773830414),
#  ('bic', 0.19613397121429443),
#  ('sepa-mandate', 0.19369162619113922),
#  ('karten_sperren', 0.19232672452926636),
#  ('nichtveranlagungsbescheinigung', 0.19229626655578613),
#  ('versichern', 0.19168566167354584),
#  ('energiesperre', 0.19088199734687805),
#  ('hilfe', 0.19012512266635895),
#  ('steuererklärung', 0.18953567743301392),
#  ('handys', 0.18563717603683472),
#  ('abwickeln', 0.1851639598608017),
#  ('didibank2', 0.1840965747833252),
#  ('als_referenzkonto', 0.18344929814338684),
#  ('kontobewegungen', 0.18332025408744812),
#  ('registrierungsvorgang', 0.1829143911600113),
#  ('zahlungsverkehrssoftware', 0.18188759684562683),
#  ('börsenaufträge', 0.181064635515213),
#  ('gegenkonto', 0.18096131086349487),
#  ('uneingeschränkt', 0.1803217977285385),
#  ('nachweis', 0.17851535975933075),
#  ('auslandsüberweisungen', 0.17815807461738586),
#  ('divers', 0.17792321741580963),
#  ('kirchensteuer', 0.17730644345283508),
#  ('kondition', 0.17674028873443604),
#  ('online-formular', 0.17673175036907196),
#  ('lastschrift', 0.17626990377902985),
#  ('onlinebanking-erweiterung', 0.17626787722110748),
#  ('firmen-lastschriftmandat', 0.1757422238588333),
#  ('handelszeit', 0.17544448375701904),
#  ('gesetzlich_vorgeben', 0.17529818415641785),
#  ('detailansicht', 0.17395339906215668),
#  ('bgh-urteil', 0.17214684188365936),
#  ('verstoßen', 0.17184479534626007),
#  ('disporahmen', 0.17105412483215332),
#  ('jahressteuerbescheinigung', 0.1699824333190918),
#  ('nachdenken', 0.16912883520126343),
#  ('einlagensicherung', 0.16744858026504517),
#  ('regulieren', 0.16737306118011475),
#  ('haftend_eigenkapital', 0.16722603142261505),
#  ('per_e-mail_an_email', 0.16624587774276733),
#  ('trojanisch_pferd', 0.1660628467798233),
#  ('aufnahme', 0.16596241295337677),
#  ('stop-loss-order', 0.16492995619773865),
#  ('kreditsicherheiten', 0.16413532197475433),
#  ('schadsoftware', 0.1631700098514557),
#  ('monatliche_raten', 0.16260141134262085),
#  ('marktlage', 0.16206270456314087),
#  ('einnahmen', 0.16155597567558289),
#  ('mietrückstände', 0.1613895148038864),
#  ('offline-version', 0.15929102897644043),
#  ('demoversion', 0.1588645577430725),
#  ('eigenmittel', 0.15882165729999542),
#  ('mastercard_direkt', 0.1583768129348755),
#  ('konto', 0.15803754329681396),
#  ('leser', 0.1578061729669571),
#  ('absichern', 0.15773946046829224),
#  ('überweisung', 0.15689264237880707),
#  ('verbindlichkeit', 0.15674158930778503),
#  ('tan-generator', 0.1561523973941803),
#  ('luxemburgische', 0.1561286300420761),
#  ('verbindung', 0.1539660096168518),
#  ('bescheinigung', 0.15380872786045074),
#  ('kreditantrag', 0.15367010235786438),
#  ('disagio', 0.15352900326251984),
#  ('app', 0.15339723229408264),
#  ('digipass', 0.15336385369300842),
#  ('anhang', 0.15272068977355957),
#  ('woche', 0.15255947411060333),
#  ('computerprogramme', 0.1524999439716339),
#  ('mitlesen', 0.15240183472633362),
#  ('analyse', 0.152061328291893),
#  ('minute', 0.1520552635192871),
#  ('berufen', 0.1518315225839615),
#  ('sepa-mandat', 0.15172122418880463),
#  ('alternativbanken', 0.15149354934692383),
#  ('empfängerdaten', 0.15135547518730164),
#  ('sicherungsverfahren', 0.15036672353744507),
#  ('online-banking_app', 0.15033501386642456),
#  ('sparcard', 0.1501833200454712),
#  ('entschädigungsfall', 0.14991003274917603),
#  ('mitarbeiter_deutsche', 0.14973992109298706),
#  ('kreditkartenrückzahlung', 0.14973825216293335),
#  ('an_börse', 0.1496499627828598),
#  ('eingeräumt_kontoüberziehung_dispo', 0.14955027401447296),
#  ('3d_secure-code', 0.1494148224592209),
#  ('anlagebetrag', 0.14924289286136627),
#  ('vorgeben', 0.14919793605804443)]

# %%
model.most_similar('eigenkapital',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('skimming', 0.3303704857826233),
#  ('doppeleinreichung', 0.2914360463619232),
#  ('schütze', 0.2901567816734314),
#  ('schildern', 0.28132250905036926),
#  ('kassenterminal', 0.2659643888473511),
#  ('methode', 0.2659575939178467),
#  ('mitgliedschaftsanteil', 0.25752121210098267),
#  ('mobiltelefonnummer', 0.2501510977745056),
#  ('darlehensnehmer', 0.2430272251367569),
#  ('bis_euro', 0.23947499692440033),
#  ('schlüsseln', 0.23889502882957458),
#  ('betriebsmittelkredit', 0.23863600194454193),
#  ('bankomatkarte', 0.23642265796661377),
#  ('eigenmittel', 0.23519347608089447),
#  ('interessent', 0.23518913984298706),
#  ('preiswert', 0.23445698618888855),
#  ('stornierung', 0.23421117663383484),
#  ('mobilnummer', 0.233610600233078),
#  ('online-version', 0.2318873107433319),
#  ('ergänzung', 0.231638565659523),
#  ('einlösung', 0.23120059072971344),
#  ('girokontonummer', 0.22560690343379974),
#  ('erbringung', 0.22557757794857025),
#  ('krankheit', 0.22469688951969147),
#  ('festgelder', 0.22428110241889954),
#  ('lohnpfändung', 0.2239016890525818),
#  ('senken', 0.22140227258205414),
#  ('erteilung', 0.22137834131717682),
#  ('zinszahlung', 0.2206224501132965),
#  ('sepa-überweisung', 0.21743501722812653),
#  ('pfändbar', 0.21643662452697754),
#  ('termingeld_festgeld_didibank', 0.21618784964084625),
#  ('auftragsarten', 0.2159358114004135),
#  ('internet-zugang', 0.21522307395935059),
#  ('aktualisiere', 0.21447619795799255),
#  ('heirat', 0.21218276023864746),
#  ('mikrofinanzfonds', 0.21119892597198486),
#  ('ä.', 0.21061719954013824),
#  ('kaufnebenkosten', 0.2105589061975479),
#  ('pop-ups', 0.21039041876792908),
#  ('geldanlageprodukten', 0.20978260040283203),
#  ('immobilienkredit', 0.20950771868228912),
#  ('freiberuflern', 0.20805080235004425),
#  ('ausdrücken', 0.2058040201663971),
#  ('mitlesen', 0.2057662457227707),
#  ('großbuchstabe', 0.2055157870054245),
#  ('festlegung', 0.20530396699905396),
#  ('kleinbuchstaben', 0.204726442694664),
#  ('bloß', 0.20461677014827728),
#  ('ai', 0.20446325838565826),
#  ('lebenssituation', 0.2043759822845459),
#  ('tan-liste', 0.20412075519561768),
#  ('optisch', 0.20313194394111633),
#  ('jahressteuerbescheinigung', 0.20302921533584595),
#  ('aufladung', 0.20181052386760712),
#  ('vorgehensweise', 0.2017204463481903),
#  ('sonderzahlung', 0.19998864829540253),
#  ('kreditkarteninhaber', 0.19980835914611816),
#  ('didibank_ag', 0.19952082633972168),
#  ('zusatz', 0.19885766506195068),
#  ('hauptwohnsitz', 0.19878453016281128),
#  ('willenserklärung', 0.1979493498802185),
#  ('sicherungsverfahren', 0.19711934030056),
#  ('didi_family', 0.1969785988330841),
#  ('treuhand', 0.19667184352874756),
#  ('kreditsicherheiten', 0.1964845210313797),
#  ('einzelfall', 0.19634336233139038),
#  ('code', 0.19634291529655457),
#  ('exakt', 0.19628463685512543),
#  ('konto-sofortcheck', 0.1959703415632248),
#  ('teilrückzahlung', 0.19580882787704468),
#  ('transportprotokoll', 0.19576990604400635),
#  ('expertenantwort', 0.194999098777771),
#  ('einzelkonten', 0.19462212920188904),
#  ('transaktionsnummer_tan', 0.1943558305501938),
#  ('leser', 0.1943252682685852),
#  ('gez', 0.19416776299476624),
#  ('didisupersparkonto', 0.19272124767303467),
#  ('unwahrscheinlich', 0.19184130430221558),
#  ('zur_nutzung', 0.19136884808540344),
#  ('legitimierung', 0.19036100804805756),
#  ('privatrente', 0.190164715051651),
#  ('sicher_verbindung', 0.189522847533226),
#  ('zielkonto', 0.18861989676952362),
#  ('unterhaltspflichten', 0.1879836767911911),
#  ('interhyp', 0.1868826299905777),
#  ('verschieben', 0.1866610050201416),
#  ('frage_wenden', 0.18620344996452332),
#  ('webid', 0.18356187641620636),
#  ('reisepass', 0.18232257664203644),
#  ('offiziell', 0.18231706321239471),
#  ('prüfen_ob', 0.1819029301404953),
#  ('vorschusszins', 0.1815841645002365),
#  ('kontowechselhilfe', 0.18079335987567902),
#  ('anschlussfinanzierung', 0.18061748147010803),
#  ('bezeichnen', 0.1804267019033432),
#  ('verhalten', 0.18023131787776947),
#  ('auszahlungsauftrag', 0.18016499280929565),
#  ('kamprad', 0.1795971840620041),
#  ('darlehenshöhe', 0.17959469556808472)]

# %%
model.most_similar('wertpapier',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('mietvertrag', 0.2224707454442978),
#  ('kreditentscheidung', 0.21485240757465363),
#  ('realtime-kurse', 0.20931968092918396),
#  ('vermieter', 0.20532070100307465),
#  ('kapitalertrag', 0.2017800509929657),
#  ('login', 0.19919328391551971),
#  ('zahlungsempfänger', 0.19610661268234253),
#  ('wechselkurs', 0.19200730323791504),
#  ('einzug', 0.1882658153772354),
#  ('lebenssituation', 0.186726376414299),
#  ('auktion', 0.18539005517959595),
#  ('domain', 0.18489137291908264),
#  ('insolvenzverwalter', 0.18083184957504272),
#  ('in_niederlande', 0.1792091578245163),
#  ('profil', 0.1764468401670456),
#  ('eu-richtlinie', 0.17565128207206726),
#  ('zinssatz', 0.1737940013408661),
#  ('fairworldfonds', 0.17355883121490479),
#  ('kuponzahltag', 0.17344066500663757),
#  ('frist', 0.1729482114315033),
#  ('steuerfrei', 0.17280720174312592),
#  ('vorschlag', 0.1721302717924118),
#  ('geburtstag', 0.17196767032146454),
#  ('neu_karten', 0.17092150449752808),
#  ('inlandsüberweisung', 0.1708693653345108),
#  ('regelung', 0.17041075229644775),
#  ('scheckeinreichungen', 0.16770945489406586),
#  ('beteiligen', 0.1665946990251541),
#  ('geburt', 0.16659216582775116),
#  ('bis_zu_euro', 0.16654418408870697),
#  ('€_€', 0.16531194746494293),
#  ('unvollständig', 0.16499033570289612),
#  ('anteil', 0.16436533629894257),
#  ('zugangsdaten', 0.16430644690990448),
#  ('feiertagen', 0.16386005282402039),
#  ('einrechnen', 0.1637316346168518),
#  ('eu-mitgliedsstaaten', 0.16322331130504608),
#  ('beratung', 0.1628568321466446),
#  ('agieren', 0.16197893023490906),
#  ('ausfall', 0.16069629788398743),
#  ('aktivierungsbrief', 0.15938006341457367),
#  ('marktlage', 0.1585642397403717),
#  ('einstandskurs', 0.15848751366138458),
#  ('kfw', 0.156748965382576),
#  ('folgen', 0.156670480966568),
#  ('festgeld-verrechnungskonto', 0.15656059980392456),
#  ('einzelvertrag', 0.1565568745136261),
#  ('bedarfsgemeinschaft', 0.15585185587406158),
#  ('kupon', 0.15576687455177307),
#  ('postident-legitimation', 0.15575151145458221),
#  ('gruppe', 0.15512330830097198),
#  ('spareinlagen', 0.154976025223732),
#  ('anfang', 0.15432855486869812),
#  ('ländergrenzen', 0.15431062877178192),
#  ('steuerpflicht', 0.15390998125076294),
#  ('euro', 0.15379345417022705),
#  ('kreditprüfung', 0.15368019044399261),
#  ('uhr', 0.1531849205493927),
#  ('otp', 0.1531803458929062),
#  ('intervall', 0.15208867192268372),
#  ('vr-kennung', 0.15186379849910736),
#  ('tipp', 0.15142865478992462),
#  ('nunmehr', 0.15136975049972534),
#  ('kreditzins', 0.1507607251405716),
#  ('tigerstarker', 0.15071463584899902),
#  ('postmitarbeiter', 0.15055690705776215),
#  ('referenzwert', 0.1504366397857666),
#  ('yapı_kredi_bank', 0.15036612749099731),
#  ('kursrückgang', 0.14990819990634918),
#  ('umstand', 0.14980551600456238),
#  ('abmelden', 0.14976078271865845),
#  ('soll', 0.1497202068567276),
#  ('hersteller', 0.1490095555782318),
#  ('personalausweise', 0.14876973628997803),
#  ('marke', 0.1487329751253128),
#  ('börsenplatz', 0.14861205220222473),
#  ('gesellschaftlich', 0.14858824014663696),
#  ('kundenbetreuer', 0.14858675003051758),
#  ('gemeldet', 0.14858512580394745),
#  ('ex-dividende-tag', 0.1484602689743042),
#  ('kaufwerte', 0.14771705865859985),
#  ('cookies', 0.1476249247789383),
#  ('treuhänder', 0.14735087752342224),
#  ('didibank_ag', 0.14726310968399048),
#  ('beginnen', 0.14723001420497894),
#  ('depotübertrag', 0.14666050672531128),
#  ('muß', 0.14590807259082794),
#  ('webid', 0.14559723436832428),
#  ('bit', 0.14556384086608887),
#  ('möglichst', 0.14538490772247314),
#  ('in_zukunft', 0.14529995620250702),
#  ('währungsumrechnung', 0.1451384574174881),
#  ('geöffnet', 0.14407280087471008),
#  ('bruchstück', 0.1440684199333191),
#  ('p-konto', 0.14398273825645447),
#  ('8:30', 0.14391499757766724),
#  ('stehend', 0.14361558854579926),
#  ('börsentag', 0.14352938532829285),
#  ('identitätsprüfung', 0.14280563592910767),
#  ('zweigstelle', 0.1427823156118393)]

# %%
model.most_similar('geschäftskonto',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('festgeldkonto', 0.2519984841346741),
#  ('augbde71net', 0.2425272911787033),
#  ('geschäftskonto_eröffnen', 0.23144952952861786),
#  ('anrufen', 0.23104341328144073),
#  ('top-girokonto', 0.21833178400993347),
#  ('p-konto', 0.2151876837015152),
#  ('weiteres', 0.21353882551193237),
#  ('brokerage', 0.2125626504421234),
#  ('zahlen', 0.21020445227622986),
#  ('einleger', 0.20890945196151733),
#  ('didi_bankcard', 0.20832504332065582),
#  ('überweisung', 0.20660938322544098),
#  ('u18-konto', 0.20588278770446777),
#  ('sperrvermerk', 0.20468014478683472),
#  ('quellen', 0.20345108211040497),
#  ('guthabenverzinsung', 0.20331712067127228),
#  ('pc_tablet_smartphone', 0.2032206505537033),
#  ('einholung', 0.2010228931903839),
#  ('neu_banking_brokerage', 0.19768397510051727),
#  ('dispokredit', 0.19679179787635803),
#  ('antragsunterlagen', 0.19614604115486145),
#  ('auszug', 0.1960497498512268),
#  ('finanzstatus', 0.19502541422843933),
#  ('versicherungsschutz', 0.19422857463359833),
#  ('mietvertrag', 0.19350706040859222),
#  ('auszahlungsauftrag', 0.19259151816368103),
#  ('englische', 0.19203254580497742),
#  ('schaden', 0.1914522647857666),
#  ('festgeld-konto', 0.1912912130355835),
#  ('debit_mastercard', 0.18990541994571686),
#  ('geheimzahl', 0.18990176916122437),
#  ('nachfinanzierungen', 0.1897139549255371),
#  ('agb', 0.18775837123394012),
#  ('annuitätendarlehen', 0.1875234842300415),
#  ('wkn', 0.18724149465560913),
#  ('hier', 0.18673892319202423),
#  ('baugeld', 0.18600916862487793),
#  ('identität', 0.1860077828168869),
#  ('bep', 0.18461568653583527),
#  ('schuldnerberatungsstelle', 0.18435128033161163),
#  ('didisupersparkonto', 0.18394441902637482),
#  ('genialcard', 0.1836092174053192),
#  ('muss_beachten', 0.18199004232883453),
#  ('sage', 0.18178622424602509),
#  ('zahlvorgang', 0.1807551383972168),
#  ('minute', 0.18055804073810577),
#  ('alleinerziehend', 0.17918826639652252),
#  ('18_geburtstag', 0.17872034013271332),
#  ('demoversion', 0.17866350710391998),
#  ('arbeit', 0.17833222448825836),
#  ('verbleiben', 0.17785046994686127),
#  ('zeitlich', 0.17696264386177063),
#  ('kind', 0.17690980434417725),
#  ('veranlagen', 0.17657998204231262),
#  ('kontaktlos_zahlung', 0.17623646557331085),
#  ('manchmal', 0.1762242466211319),
#  ('online-shopping', 0.1757170855998993),
#  ('einverständnis', 0.17541098594665527),
#  ('bis_zur_höhe', 0.1753409504890442),
#  ('meldung', 0.17453500628471375),
#  ('kartenzusatzleistungen', 0.17409610748291016),
#  ('solaris', 0.17352205514907837),
#  ('referenzwert', 0.172322079539299),
#  ('gebrauchtwagen', 0.17210933566093445),
#  ('persönlich_einstellung', 0.17210045456886292),
#  ('entwickeln', 0.17147183418273926),
#  ('euro-zahlungsverkehrsraum', 0.17106735706329346),
#  ('sicherheitsmedium', 0.17082209885120392),
#  ('sparcard', 0.17079655826091766),
#  ('sepa-mandate', 0.17053893208503723),
#  ('kaufen', 0.1698128879070282),
#  ('versicherungsleistungen', 0.16976886987686157),
#  ('perfekt', 0.16875232756137848),
#  ('mal', 0.1673232913017273),
#  ('zusätzlich_kosten', 0.1672697365283966),
#  ('problem', 0.16718730330467224),
#  ('festgeld', 0.16709837317466736),
#  ('steueransässigkeit', 0.16692718863487244),
#  ('filialnummer', 0.16690313816070557),
#  ('wohnung', 0.16674979031085968),
#  ('kunde', 0.16664990782737732),
#  ('nettoeinkommen', 0.16661101579666138),
#  ('online-version', 0.16606014966964722),
#  ('vl-sparvertrag', 0.16576611995697021),
#  ('laufzeiten', 0.16562873125076294),
#  ('herz', 0.16554726660251617),
#  ('bezahlen', 0.16554392874240875),
#  ('wert', 0.16515380144119263),
#  ('vorsichtig', 0.16363926231861115),
#  ('dispozins', 0.16287444531917572),
#  ('erspartes', 0.16231712698936462),
#  ('entstanden', 0.16213063895702362),
#  ('weisung', 0.1620665192604065),
#  ('verbraucherinsolvenzverfahren', 0.16197200119495392),
#  ('sms-tan', 0.16189813613891602),
#  ('freibetrag', 0.16143590211868286),
#  ('tagesgeldkonto', 0.16094465553760529),
#  ('algorithmen', 0.16076593101024628),
#  ('dauerauftrag', 0.16040384769439697),
#  ('heimatnetz', 0.16015653312206268)]

# %%
model.most_similar('erteilen',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('ablehnen', 0.2498653531074524),
#  ('lediglich', 0.22757814824581146),
#  ('erstatten', 0.22331847250461578),
#  ('verhandeln', 0.21924921870231628),
#  ('beantragen', 0.21511094272136688),
#  ('einreichen', 0.21496053040027618),
#  ('aktualisieren', 0.21387678384780884),
#  ('erheben', 0.21029286086559296),
#  ('registrieren', 0.20707397162914276),
#  ('mindestens_monat', 0.20471040904521942),
#  ('sinken', 0.20142313838005066),
#  ('vornehmen', 0.200678288936615),
#  ('erfasst', 0.20002451539039612),
#  ('ausgenutzt', 0.19879011809825897),
#  ('übernehmen', 0.19851262867450714),
#  ('verbessern', 0.19845795631408691),
#  ('treten', 0.19838374853134155),
#  ('zuteilen', 0.19505274295806885),
#  ('prüfen', 0.19484463334083557),
#  ('vertreten', 0.1945895552635193),
#  ('jetzig', 0.19431576132774353),
#  ('verschlüsseln_übertragen', 0.193115234375),
#  ('daran_dass', 0.1917732208967209),
#  ('falsch_eingeben', 0.18868432939052582),
#  ('leistung', 0.1870272159576416),
#  ('herausfiltern', 0.18608827888965607),
#  ('eingeloggt', 0.18531833589076996),
#  ('ablösen', 0.18475684523582458),
#  ('wahl_zwischen', 0.18467049300670624),
#  ('zugunsten', 0.18137095868587494),
#  ('lieb', 0.17949002981185913),
#  ('annehmen', 0.17931625247001648),
#  ('anschaffung', 0.17515897750854492),
#  ('absichern', 0.17446082830429077),
#  ('kreditnehmer', 0.1739041805267334),
#  ('arbeitsplatz', 0.17362216114997864),
#  ('mitteilen', 0.1732565462589264),
#  ('beachten', 0.17212584614753723),
#  ('pfänden', 0.17204397916793823),
#  ('abspeichern', 0.17194333672523499),
#  ('vorliegen', 0.17168453335762024),
#  ('treffen', 0.17094670236110687),
#  ('bezahlterminal', 0.16998586058616638),
#  ('eingabeaufforderung', 0.16950270533561707),
#  ('service', 0.16762952506542206),
#  ('entdecken', 0.1676224023103714),
#  ('unfall', 0.16721123456954956),
#  ('rechtlich', 0.16708725690841675),
#  ('abgeben', 0.16617947816848755),
#  ('vornehm', 0.1631697416305542),
#  ('vergessen_habe', 0.1625673770904541),
#  ('leiten', 0.1623474657535553),
#  ('geben', 0.1622869372367859),
#  ('entschlüsseln', 0.16135701537132263),
#  ('kundenbetreuung', 0.16119521856307983),
#  ('eingeben', 0.15998727083206177),
#  ('klasse', 0.15839843451976776),
#  ('of', 0.15830644965171814),
#  ('zusammengefasst', 0.15735086798667908),
#  ('beleghaften', 0.1569168120622635),
#  ('rechtsverbindlich', 0.1560155153274536),
#  ('absenden', 0.15561041235923767),
#  ('zurückrufen', 0.15554983913898468),
#  ('einlegen', 0.15522584319114685),
#  ('aktiv', 0.15411075949668884),
#  ('anfällen', 0.1539185345172882),
#  ('klicken_dazu', 0.15319418907165527),
#  ('untersuchen', 0.15279579162597656),
#  ('zahlen', 0.15211014449596405),
#  ('zurückgreifen', 0.1518290787935257),
#  ('aufschieben', 0.15148387849330902),
#  ('versicherer', 0.15146096050739288),
#  ('zuletzt', 0.15045922994613647),
#  ('einzeltransaktionen', 0.14985650777816772),
#  ('papier', 0.14982180297374725),
#  ('angeben', 0.14971233904361725),
#  ('sammeln', 0.1493247151374817),
#  ('ausführungsdatum', 0.1489553600549698),
#  ('wunschtermin', 0.14816340804100037),
#  ('örtlich', 0.14798426628112793),
#  ('vergessen', 0.14667293429374695),
#  ('vorbereiten', 0.14662495255470276),
#  ('überweisen', 0.14658911526203156),
#  ('verzug', 0.1459919959306717),
#  ('bezahlen', 0.14577795565128326),
#  ('bitten_halten', 0.14564034342765808),
#  ('überwinden', 0.14530164003372192),
#  ('authentifizieren', 0.14484432339668274),
#  ('leasingobjekte', 0.14451882243156433),
#  ('auszahlen', 0.1426842361688614),
#  ('rechtmäßig', 0.1425115019083023),
#  ('zeichnen', 0.14238739013671875),
#  ('extra-konto', 0.14235232770442963),
#  ('mitteil', 0.1418120115995407),
#  ('übermitteln', 0.14172501862049103),
#  ('genügen', 0.14171674847602844),
#  ('einlösung', 0.1416875272989273),
#  ('offen', 0.14145126938819885),
#  ('sparbrief', 0.14131110906600952),
#  ('postalisch', 0.14130589365959167)]

# %%
model.most_similar('lastschrift',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('beruhen', 0.22398068010807037),
#  ('cent', 0.21497420966625214),
#  ('lastschrifteinzug', 0.2075050175189972),
#  ('angreifer', 0.20465804636478424),
#  ('marktentwicklung', 0.20029331743717194),
#  ('girocard', 0.19817784428596497),
#  ('rate', 0.196637824177742),
#  ('kartenverlust', 0.1957760453224182),
#  ('immobilienkredit', 0.19288237392902374),
#  ('zurückfordern', 0.1903497725725174),
#  ('kontonummer', 0.18893946707248688),
#  ('anpassung', 0.18855218589305878),
#  ('angegeben_referenzkonto', 0.18826234340667725),
#  ('tan-generator', 0.18701568245887756),
#  ('bisherig_bank', 0.18640300631523132),
#  ('als_gesetzliche_r_vertreter', 0.1852133572101593),
#  ('meldepflicht', 0.18079952895641327),
#  ('monat', 0.18052470684051514),
#  ('auftragsart', 0.1793755292892456),
#  ('didisparkonto-', 0.17838577926158905),
#  ('didisupersparkonto-konto', 0.17730534076690674),
#  ('kontobewegungen', 0.1769854724407196),
#  ('freistellungsauftrag', 0.17626990377902985),
#  ('kündigungsschreiben', 0.17484654486179352),
#  ('benutzung', 0.17463332414627075),
#  ('smartüberweisung', 0.17354372143745422),
#  ('rechtsanwalt', 0.1734725683927536),
#  ('wachsen', 0.17312508821487427),
#  ('fremdbank', 0.1728522926568985),
#  ('zugreifen', 0.17255215346813202),
#  ('pushtan', 0.17221985757350922),
#  ('karten_sperren', 0.1721368283033371),
#  ('bankdaten', 0.1717926561832428),
#  ('referenz', 0.17163079977035522),
#  ('kontonummer_bankleitzahl', 0.1716177761554718),
#  ('referenznummer', 0.1710706651210785),
#  ('veränderung', 0.17099130153656006),
#  ('geschäftstag', 0.170772984623909),
#  ('didi_ode', 0.17041191458702087),
#  ('karten', 0.16950275003910065),
#  ('zins', 0.16896724700927734),
#  ('uneingeschränkt', 0.1687881052494049),
#  ('umziehen', 0.16841267049312592),
#  ('alias', 0.16682204604148865),
#  ('tatsächliche', 0.1663333773612976),
#  ('dispo-rahmenvereinbarung', 0.16584263741970062),
#  ('online-transaktionen', 0.16576537489891052),
#  ('reiter_service', 0.16535502672195435),
#  ('baudarlehen', 0.16479679942131042),
#  ('jailbreak', 0.16270582377910614),
#  ('geldabheben', 0.16179437935352325),
#  ('laufend_jahr', 0.16166377067565918),
#  ('greifen', 0.16060276329517365),
#  ('regional', 0.1596013307571411),
#  ('kreditantrag', 0.15870849788188934),
#  ('ermessen', 0.15845800936222076),
#  ('gründlich', 0.15838098526000977),
#  ('entgelt', 0.1582820862531662),
#  ('mitarbeiter', 0.15771935880184174),
#  ('zahlungsunfähig', 0.157357856631279),
#  ('abkomme', 0.15696413815021515),
#  ('gesetzlich_vorgeben', 0.1565527319908142),
#  ('didilogin', 0.1558782160282135),
#  ('chiptan-verfahren', 0.15553836524486542),
#  ('beeinflussen', 0.15544667840003967),
#  ('bargeldverfügung', 0.15515956282615662),
#  ('adressänderung', 0.15437254309654236),
#  ('leasingobjekt', 0.15420645475387573),
#  ('iban_bic', 0.15377871692180634),
#  ('ausgeben', 0.15365424752235413),
#  ('führung', 0.15321047604084015),
#  ('kundin', 0.15294714272022247),
#  ('liefern', 0.15257006883621216),
#  ('dispozins', 0.15238893032073975),
#  ('verfügen', 0.1518506109714508),
#  ('befallen', 0.15177293121814728),
#  ('bürgschaft', 0.151131272315979),
#  ('didi_bank', 0.1509062647819519),
#  ('wenden_bitte', 0.15074443817138672),
#  ('itan', 0.15041492879390717),
#  ('in_voll_umfang', 0.15036073327064514),
#  ('scoring', 0.1499944031238556),
#  ('mietkautionsbürgschaften', 0.1496945470571518),
#  ('beheben', 0.14925482869148254),
#  ('garantieren', 0.14852821826934814),
#  ('maus', 0.14841070771217346),
#  ('kaufnebenkosten', 0.1482369303703308),
#  ('sorgfaltspflichten', 0.14819207787513733),
#  ('einrichtung', 0.14699095487594604),
#  ('englisch', 0.14621949195861816),
#  ('kreditvergabe', 0.14564411342144012),
#  ('zentrale', 0.14547577500343323),
#  ('versichern', 0.1453433632850647),
#  ('lebenslang', 0.14530713856220245),
#  ('mietkosten', 0.14501696825027466),
#  ('datenübertragung', 0.14487051963806152),
#  ('angelegenheit', 0.14424899220466614),
#  ('gerade', 0.14403869211673737),
#  ('zahlungsverkehrsprogramm', 0.14401084184646606),
#  ('wertpapiergeschäft', 0.14378319680690765)]

# %%
model.most_similar('bank',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('privatbank', 0.24138228595256805),
#  ('gläubigers', 0.2247702032327652),
#  ('beim_bundeszentralamt_für_steuer', 0.22131803631782532),
#  ('mindestens_monat', 0.2150251716375351),
#  ('gegenwert', 0.2105567753314972),
#  ('vorgegeben', 0.2077471911907196),
#  ('spät', 0.2038988173007965),
#  ('unzutreffend', 0.20361551642417908),
#  ('handelspartner', 0.20305392146110535),
#  ('telefonisch', 0.19844147562980652),
#  ('abkomme', 0.19706957042217255),
#  ('banken', 0.19654223322868347),
#  ('programm', 0.19631777703762054),
#  ('poltawiens', 0.19477516412734985),
#  ('freunden', 0.19452513754367828),
#  ('zuverlässigkeit', 0.1942770630121231),
#  ('teilnehmer', 0.19324783980846405),
#  ('%_%', 0.19197311997413635),
#  ('person', 0.1911144256591797),
#  ('neu_registrierungsbrief', 0.18920327723026276),
#  ('verbesserung', 0.1876925528049469),
#  ('ander_bank', 0.1875501424074173),
#  ('rollen', 0.1857154220342636),
#  ('foto', 0.18540340662002563),
#  ('finanzinstitute', 0.1830846667289734),
#  ('legitim', 0.18061870336532593),
#  ('grafik', 0.18007217347621918),
#  ('zulassungsstelle', 0.17835351824760437),
#  ('einspruch', 0.17806674540042877),
#  ('bargeldtransaktionen', 0.17715990543365479),
#  ('religionszugehörigkeit', 0.17561282217502594),
#  ('geschäftsfähig', 0.17432649433612823),
#  ('zwangsvollstreckung', 0.17197716236114502),
#  ('geschäftsbank', 0.1715620905160904),
#  ('deutsche_handelsbank', 0.17071744799613953),
#  ('six', 0.17031124234199524),
#  ('miteinander', 0.17026494443416595),
#  ('hacker', 0.1693868786096573),
#  ('freigabe', 0.16887101531028748),
#  ('kennwort', 0.16859617829322815),
#  ('anspruch', 0.1679021269083023),
#  ('meldung', 0.16756148636341095),
#  ('unzulässig', 0.16710002720355988),
#  ('pensionär', 0.1664983481168747),
#  ('kartennummer', 0.1655418574810028),
#  ('nachweisen', 0.16502602398395538),
#  ('eigenständige', 0.16500583291053772),
#  ('erst-pin', 0.16426272690296173),
#  ('auftreten', 0.16219939291477203),
#  ('tageskonto', 0.16211479902267456),
#  ('online-überweisungen', 0.1612773835659027),
#  ('staatsangehörigkeit', 0.1610345095396042),
#  ('geschäftsstelle', 0.16091151535511017),
#  ('ehegattenübergreifende_verlustverrechnung', 0.16087141633033752),
#  ('erneut_durchlaufen', 0.1607225090265274),
#  ('erwähnen', 0.1605585366487503),
#  ('user', 0.16005748510360718),
#  ('einziehen', 0.15931814908981323),
#  ('giro_direkt', 0.15905971825122833),
#  ('zeichnen', 0.1583467572927475),
#  ('eilauftrag', 0.15825456380844116),
#  ('entnehmen_bitte_preisverzeichnis_leistungsverzeichnis',
#   0.15749481320381165),
#  ('express', 0.15723469853401184),
#  ('pflicht', 0.15702633559703827),
#  ('tagesgeld', 0.15682676434516907),
#  ('margin_account', 0.15609140694141388),
#  ('aufladung', 0.1547689437866211),
#  ('kontinuierlich', 0.15445098280906677),
#  ('dienst', 0.1541144847869873),
#  ('inhaber', 0.15410254895687103),
#  ('identifikationsverfahren', 0.15393412113189697),
#  ('riestervertrag', 0.15380416810512543),
#  ('lösung', 0.15338808298110962),
#  ('fertig', 0.15236172080039978),
#  ('sicherungsverfahren', 0.15173101425170898),
#  ('praktisch', 0.15171559154987335),
#  ('steuerlich_ansässigkeit', 0.15139438211917877),
#  ('stammen', 0.151142880320549),
#  ('maestro-card', 0.15101061761379242),
#  ('sinnen', 0.15023250877857208),
#  ('steuerbehörden', 0.15007668733596802),
#  ('automatenbetreiber', 0.14954592287540436),
#  ('ort', 0.14912711083889008),
#  ('nach_eingabe', 0.14909251034259796),
#  ('alternative', 0.14905042946338654),
#  ('finanzdienstleistungsunternehmen', 0.1487235128879547),
#  ('chiptan-verfahren', 0.1487146019935608),
#  ('faktor', 0.14845630526542664),
#  ('aktivierung', 0.14810562133789062),
#  ('didibank_gmbh_oglietzen', 0.1473512500524521),
#  ('kauf', 0.14730146527290344),
#  ('dididispo', 0.1471959501504898),
#  ('gehaltsbescheinigung', 0.1468966007232666),
#  ('wo', 0.1468869149684906),
#  ('wohnung', 0.14663352072238922),
#  ('wertpapierfirmen', 0.1462940126657486),
#  ('schließung', 0.14621154963970184),
#  ('verbleiben', 0.14616158604621887),
#  ('anonym', 0.1460479199886322),
#  ('kontonummer_bankleitzahl', 0.14582005143165588)]

# %%
model.most_similar('steuern',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('an_finanzamt_abführen', 0.34834226965904236),
#  ('erzeugen', 0.2643846571445465),
#  ('eingangsmonat', 0.2529135048389435),
#  ('errechnen', 0.24769043922424316),
#  ('werben', 0.24395740032196045),
#  ('belgische', 0.24124182760715485),
#  ('schutzbetrag', 0.23422397673130035),
#  ('abgesehen', 0.23170405626296997),
#  ('insoweit', 0.2316422015428543),
#  ('postbote', 0.2312406599521637),
#  ('reise', 0.2299083173274994),
#  ('anrechnen', 0.22919495403766632),
#  ('land', 0.2238059788942337),
#  ('pfändungs', 0.22271929681301117),
#  ('didibank_ag', 0.2215963751077652),
#  ('kombi', 0.22084109485149384),
#  ('pb', 0.21935388445854187),
#  ('3d_secure', 0.21706196665763855),
#  ('didibank-konto', 0.21655555069446564),
#  ('nachrangkapital', 0.21644078195095062),
#  ('datensatz', 0.213889941573143),
#  ('herausfinden', 0.21380075812339783),
#  ('gültigkeitsdatum', 0.21302631497383118),
#  ('verbuchen', 0.21291884779930115),
#  ('entschädigungsanspruch', 0.21087153255939484),
#  ('nach_registrierung', 0.20939598977565765),
#  ('folgetag', 0.20926204323768616),
#  ('vertragsunterlagen', 0.2079111486673355),
#  ('kontoinhaberin', 0.2076880782842636),
#  ('zentimeter', 0.20764166116714478),
#  ('nutzbar', 0.20717664062976837),
#  ('abdecken', 0.20559385418891907),
#  ('finanzierend', 0.2051519751548767),
#  ('mobile-banking-app', 0.2051444798707962),
#  ('einbehalten', 0.20490998029708862),
#  ('solide', 0.20411401987075806),
#  ('insgesamt', 0.2039439082145691),
#  ('sicherungspflichtige', 0.20363235473632812),
#  ('gutschriften', 0.20346133410930634),
#  ('p-konto', 0.20299217104911804),
#  ('abgeben', 0.20175155997276306),
#  ('anpasst', 0.2012888491153717),
#  ('puffer', 0.20086543262004852),
#  ('abzug', 0.19915392994880676),
#  ('entsperrt', 0.19895580410957336),
#  ('möglichst', 0.19577834010124207),
#  ('abgeltungsteuer', 0.19561748206615448),
#  ('geldbörse', 0.19528594613075256),
#  ('ombudsmann', 0.19518840312957764),
#  ('stärken', 0.19435454905033112),
#  ('zahlungsverhalten', 0.19279345870018005),
#  ('abgeltungssteuer', 0.1927429437637329),
#  ('banklizenz', 0.19272471964359283),
#  ('unternehmer', 0.19240312278270721),
#  ('schadsoftware', 0.19134429097175598),
#  ('bezeichnen', 0.19076815247535706),
#  ('bbva', 0.19061602652072906),
#  ('pauschal', 0.19059054553508759),
#  ('erkundigen', 0.1905887871980667),
#  ('postweg', 0.18979091942310333),
#  ('endgerät', 0.18837887048721313),
#  ('wohl', 0.18835711479187012),
#  ('broker', 0.1882932484149933),
#  ('transaktionsnummer', 0.18797515332698822),
#  ('aufmerksam', 0.1878935545682907),
#  ('empfänger-kontonummer', 0.18754315376281738),
#  ('rechtssicherheit', 0.18749424815177917),
#  ('standardmäßig', 0.18739838898181915),
#  ('gebieten', 0.1873166710138321),
#  ('finanzbehörden', 0.18721549212932587),
#  ('ä.', 0.18711182475090027),
#  ('auftragslimit', 0.18636150658130646),
#  ('zuordnen', 0.18582046031951904),
#  ('schließen', 0.185529887676239),
#  ('herz', 0.1852020025253296),
#  ('veranlasst', 0.18451443314552307),
#  ('infrastruktur', 0.18430064618587494),
#  ('sicherungsgrenze', 0.18401004374027252),
#  ('in_usa', 0.1839924305677414),
#  ('webrtc', 0.1833736151456833),
#  ('verlegen', 0.18288007378578186),
#  ('werfen', 0.18284818530082703),
#  ('eur', 0.18257968127727509),
#  ('abstehen', 0.18198877573013306),
#  ('pc', 0.18195950984954834),
#  ('erfahrung', 0.1815953552722931),
#  ('entgelt', 0.18142607808113098),
#  ('euroraum', 0.18063019216060638),
#  ('ratenschutz', 0.18035723268985748),
#  ('kreditrechner', 0.1799468994140625),
#  ('ausnahmefall', 0.1796693205833435),
#  ('luxemburg', 0.17910528182983398),
#  ('teilen', 0.17881076037883759),
#  ('herunterladen', 0.17870740592479706),
#  ('abstellen', 0.17773373425006866),
#  ('kirchensteuer', 0.17764177918434143),
#  ('datenbank', 0.1775331199169159),
#  ('einzelne', 0.17672988772392273),
#  ('direktbank', 0.17634081840515137),
#  ('bundeszentralamts', 0.17631664872169495)]

# %%
model.most_similar('p-konto',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('pfändungsfreibetrag', 0.2629399597644806),
#  ('höchstgrenze', 0.2501332759857178),
#  ('pharming', 0.2476796954870224),
#  ('interhyp', 0.24698109924793243),
#  ('pfändungsschutzkonto', 0.23806552588939667),
#  ('infrastruktur', 0.23786820471286774),
#  ('3d_secure-code', 0.2336156964302063),
#  ('video-ident', 0.23081599175930023),
#  ('heimatnetz', 0.2240818738937378),
#  ('führung', 0.22335512936115265),
#  ('kreditsicherheit', 0.22102858126163483),
#  ('augbde71net', 0.21850380301475525),
#  ('am_geldautomat', 0.21822501718997955),
#  ('geschäftskonto', 0.215187668800354),
#  ('riestervertrag', 0.21308623254299164),
#  ('online-verfügungsrahmen', 0.21249224245548248),
#  ('und-konto', 0.21181997656822205),
#  ('act', 0.21144217252731323),
#  ('browser', 0.21098291873931885),
#  ('booster', 0.20793874561786652),
#  ('einstieg', 0.20705625414848328),
#  ('rote', 0.20666080713272095),
#  ('mastercard_karten', 0.20650121569633484),
#  ('sperrvermerk', 0.2063608169555664),
#  ('an_finanzamt_abführen', 0.2059490978717804),
#  ('steuern', 0.20299220085144043),
#  ('kontoauszugonline', 0.1999058723449707),
#  ('basiskonto', 0.1986115276813507),
#  ('jahresultimo', 0.19846093654632568),
#  ('wieso', 0.19808512926101685),
#  ('kurzmitteilungen', 0.19678115844726562),
#  ('einblick', 0.19581380486488342),
#  ('variabel', 0.19550108909606934),
#  ('pfändungs', 0.1953723281621933),
#  ('mindesttilgung', 0.19513273239135742),
#  ('passwort_vergessen', 0.1939709335565567),
#  ('bgh-urteil', 0.19332441687583923),
#  ('bankkunden', 0.19214758276939392),
#  ('herz', 0.19198639690876007),
#  ('tan_per_sms', 0.19058895111083984),
#  ('handelszeiten', 0.18918389081954956),
#  ('maximalbetrag', 0.18893729150295258),
#  ('verwerten', 0.18882809579372406),
#  ('zahlvorgang', 0.1875186264514923),
#  ('drittschuldner', 0.18712374567985535),
#  ('kreditkarte(n', 0.18692271411418915),
#  ('anleger', 0.1847885102033615),
#  ('steuerbescheinigung', 0.18380016088485718),
#  ('reise', 0.18377602100372314),
#  ('rabatt', 0.18328677117824554),
#  ('margin_account', 0.18316343426704407),
#  ('geldbörse', 0.18232998251914978),
#  ('creditplus', 0.18231582641601562),
#  ('eingabefenstern', 0.1815546154975891),
#  ('papier', 0.18093805015087128),
#  ('händler', 0.18018843233585358),
#  ('insoweit', 0.18015332520008087),
#  ('informationsaustausch', 0.17989884316921234),
#  ('komplizieren', 0.17969393730163574),
#  ('synchronisation', 0.17889508605003357),
#  ('differenz', 0.1788126528263092),
#  ('bonität_voraussetzen', 0.17818520963191986),
#  ('finanzstatus', 0.17612379789352417),
#  ('vorzeitig_zurückzahlen', 0.17499908804893494),
#  ('video-ident-verfahren', 0.17481648921966553),
#  ('sicherheitsmedium', 0.17444691061973572),
#  ('orderkonto', 0.17345963418483734),
#  ('beruhen', 0.17314498126506805),
#  ('zusatzleistungen', 0.17273059487342834),
#  ('vorsichtig', 0.17216016352176666),
#  ('niw', 0.17188748717308044),
#  ('bereits_bestehend', 0.17135432362556458),
#  ('außerbörslichen_handeln', 0.17110316455364227),
#  ('aufheben', 0.1707722544670105),
#  ('mindestens_jahr_alt', 0.16963553428649902),
#  ('einrechnen', 0.16930986940860748),
#  ('mobil_bezahlen', 0.16907212138175964),
#  ('ambibank-girokonto', 0.16809546947479248),
#  ('monatlich_geldeingang', 0.16757017374038696),
#  ('adobe', 0.16713616251945496),
#  ('maustaste', 0.16646702587604523),
#  ('didi_kids-konto', 0.1664017289876938),
#  ('verbindung_zum', 0.16612514853477478),
#  ('equiduct', 0.16609305143356323),
#  ('schufa-freies', 0.16572944819927216),
#  ('annuitätendarlehen', 0.16571874916553497),
#  ('verkaufe', 0.16547410190105438),
#  ('virenscanner', 0.1653490960597992),
#  ('sozialamt', 0.16517093777656555),
#  ('vereinigung', 0.1648714542388916),
#  ('usa', 0.1647312343120575),
#  ('hoch_zins', 0.1644061654806137),
#  ('portfolios', 0.1643761396408081),
#  ('anwender', 0.1643631011247635),
#  ('selbstbehalt', 0.16402393579483032),
#  ('wenig', 0.1639055460691452),
#  ('umziehen', 0.16372068226337433),
#  ('sorte', 0.1634911298751831),
#  ('verändern', 0.16290703415870667),
#  ('berechtigung', 0.16253507137298584)]
